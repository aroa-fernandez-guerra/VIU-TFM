# %% [markdown]
# # Spleen 3D segmentation with MONAI
#
# Este código esta basado en el tutorial de MONAI para segmentación del bazo:
#
# https://github.com/Project-MONAI/tutorials/blob/master/3d_segmentation/spleen_segmentation_3d.ipynb
#
# Y se realizarán diversos experimentos para estudiar la precisión de una serie de modelos de segmentación.
#
# Se utilizará la librería MONAI.
#
# Los datos utilizados, imágenes de tomografía computarizada del abdomen se han obtenido de http://medicaldecathlon.com/, y son los correspondientes al *spleen dataset*. Forman parte de una de las 10 tareas de segmentación propuestas en el reto MSD 2018.
#
# Target: Spleen
# Modality: CT
# Format: NIfTI
# Size: 61 3D volumes (41 Training + 20 Testing)
# Source: Memorial Sloan Kettering Cancer Center
# Challenge: Large ranging foreground size

# %% [markdown]
# ## Setup environment

# %%
#Instalación de la librería MONAI y de matplotlib

# !python -c "import monai" || pip install -q "monai-weekly[gdown, nibabel, tqdm, ignite]"
# !python -c "import matplotlib" || pip install -q matplotlib
# %matplotlib inline

# %%
# Importación de las librerías y herramientas que se van a utilizar
from monai.utils import first, set_determinism
from monai.transforms import (
    AsDiscrete,
    AsDiscreted,
    EnsureChannelFirstd,
    Compose,
    CropForegroundd,
    LoadImaged,
    Orientationd,
    RandCropByPosNegLabeld,
    ScaleIntensityRanged,
    Spacingd,
    EnsureTyped,
    EnsureType,
    Invertd,
)
from monai.handlers.utils import from_engine
from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.metrics import DiceMetric
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.data import CacheDataset, DataLoader, Dataset, decollate_batch
from monai.config import print_config
from monai.apps import download_and_extract
import torch
import matplotlib.pyplot as plt
import tempfile
import shutil
import os
import glob

# %% [markdown]
# ## Setup data directory

# %%
# Creación de un fichero temporal de ejecución
directory = os.environ.get("MONAI_DATA_DIRECTORY")
root_dir = tempfile.mkdtemp() if directory is None else directory
print(root_dir)
# Out:
# /tmp/tmpn00i3sod

# %% [markdown]
# ## Download dataset

# %%
# Obtención del dataset de medicaldecathlon
resource = "https://msd-for-monai.s3-us-west-2.amazonaws.com/Task09_Spleen.tar"
md5 = "410d4a301da4e5b2f6f86ec3ddba524e"

compressed_file = os.path.join(root_dir, "Task09_Spleen.tar")
data_dir = os.path.join(root_dir, "Task09_Spleen")
if not os.path.exists(data_dir):
    download_and_extract(resource, compressed_file, root_dir, md5)
# Out:
# Task09_Spleen.tar: 1.50GB [01:10, 22.7MB/s]
# 2022-03-12 22:51:11,490 - INFO - Downloaded: /tmp/tmpn00i3sod/Task09_Spleen.tar
# 2022-03-12 22:51:14,506 - INFO - Verified 'Task09_Spleen.tar', md5: 410d4a301da4e5b2f6f86ec3ddba524e.
# 2022-03-12 22:51:14,508 - INFO - Writing into directory: /tmp/tmpn00i3sod.

# %% [markdown]
# ## Set MSD Spleen dataset path

# %%
# Los datos de entrenamiento se encapsulan en un diccionario junto con sus etiquetas.
# Esto va a permitir trabajar en un formato más cómodo, con la imagen y su etiqueta en la misma estructura de datos
# Y se podrá hacer uso de las funciones de tranformación de MONAI para diccionarios



train_images = sorted(
    glob.glob(os.path.join(data_dir, "imagesTr", "*.nii.gz")))
train_labels = sorted(
    glob.glob(os.path.join(data_dir, "labelsTr", "*.nii.gz")))
data_dicts = [
    {"image": image_name, "label": label_name}
    for image_name, label_name in zip(train_images, train_labels)
]


# Se separa en conjunto de test y validación
train_files, val_files = data_dicts[:-9], data_dicts[-9:]

# %% [markdown]
# ## Set deterministic training for reproducibility

# %%
set_determinism(seed=0)

# %% [markdown]
# ## Setup transforms for training and validation
#
# Here we use several transforms to augment the dataset:
# 1. `LoadImaged` loads the spleen CT images and labels from NIfTI format files.
# 1. `AddChanneld` as the original data doesn't have channel dim, add 1 dim to construct "channel first" shape.
# 1. `Orientationd` unifies the data orientation based on the affine matrix.
# 1. `Spacingd` adjusts the spacing by `pixdim=(1.5, 1.5, 2.)` based on the affine matrix.
# 1. `ScaleIntensityRanged` extracts intensity range [-57, 164] and scales to [0, 1].
# 1. `CropForegroundd` removes all zero borders to focus on the valid body area of the images and labels.
# 1. `RandCropByPosNegLabeld` randomly crop patch samples from big image based on pos / neg ratio.
# The image centers of negative samples must be in valid body area.
# 1. `RandAffined` efficiently performs `rotate`, `scale`, `shear`, `translate`, etc. together based on PyTorch affine transform.
# 1. `EnsureTyped` converts the numpy array to PyTorch Tensor for further steps.

# %%
# Concatenación de las transformaciones aplicadas los subconjuntos de train y de test

train_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys=["image", "label"]),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        Spacingd(keys=["image", "label"], pixdim=(
            1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
        ScaleIntensityRanged(
            keys=["image"], a_min=-57, a_max=164,
            b_min=0.0, b_max=1.0, clip=True,
        ),
        CropForegroundd(keys=["image", "label"], source_key="image"),
        RandCropByPosNegLabeld(
            keys=["image", "label"],
            label_key="label",
            spatial_size=(96, 96, 96),
            pos=1,
            neg=1,
            num_samples=4,
            image_key="image",
            image_threshold=0,
        ),
        EnsureTyped(keys=["image", "label"]),
    ]
)
val_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys=["image", "label"]),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        Spacingd(keys=["image", "label"], pixdim=(
            1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
        ScaleIntensityRanged(
            keys=["image"], a_min=-57, a_max=164,
            b_min=0.0, b_max=1.0, clip=True,
        ),
        CropForegroundd(keys=["image", "label"], source_key="image"),
        EnsureTyped(keys=["image", "label"]),
    ]
)

# %% [markdown]
# ## Check transforms in DataLoader

# %%
check_ds = Dataset(data=val_files, transform=val_transforms)
check_loader = DataLoader(check_ds, batch_size=1)
check_data = first(check_loader)
image, label = (check_data["image"][0][0], check_data["label"][0][0])
print(f"image shape: {image.shape}, label shape: {label.shape}")
# plot the slice [:, :, 80]
plt.figure("check", (12, 6))

for i in range(0,4):
  
  plt.subplot(1, 2, 1)
  plt.title("image")
  plt.imshow(image[:,:, 20+i*20], cmap="gray")
  plt.subplot(1, 2, 2)
  plt.title("label")
  plt.imshow(label[:, :, 20+i*20])
  plt.show()
# Out:
# image shape: torch.Size([226, 157, 113]), label shape: torch.Size([226, 157, 113])

# %% [markdown]
# ## Define CacheDataset and DataLoader for training and validation

# %%
train_ds = CacheDataset(
    data=train_files, transform=train_transforms,
    cache_rate=1.0, num_workers=4)
# train_ds = monai.data.Dataset(data=train_files, transform=train_transforms)

# use batch_size=2 to load images and use RandCropByPosNegLabeld
# to generate 2 x 4 images for network training
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=4)

val_ds = CacheDataset(
    data=val_files, transform=val_transforms, cache_rate=1.0, num_workers=4)
# val_ds = Dataset(data=val_files, transform=val_transforms)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=4)
# Out:
# Loading dataset: 100%|██████████| 32/32 [01:26<00:00,  2.71s/it]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Loading dataset: 100%|██████████| 9/9 [00:18<00:00,  2.04s/it]

# %% [markdown]
# ## Create Model, Loss, Optimizer

# %%
my_model='UNet6' 
# 'UNet5', 'RegUNet', 'SegResNet' 

if my_model=='UNet6':
  device = torch.device("cuda:0")
  model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256,512),
    strides=(2, 2, 2, 2,2,2),
    num_res_units=2,
    norm=Norm.BATCH,
  ).to(device)
  loss_function = DiceLoss(to_onehot_y=True, softmax=True)
  optimizer = torch.optim.Adam(model.parameters(), 1e-4)
  dice_metric = DiceMetric(include_background=False, reduction="mean")

elif my_model=='UNet':
  device = torch.device("cuda:0")
  model= UNet(
      spatial_dims=3,
      in_channels=1,
      out_channels=2,
      channels=(16, 32, 64, 128, 256),
      strides=(2, 2, 2, 2),
      num_res_units=2,
      norm=Norm.BATCH,
  ).to(device)
  loss_function = DiceLoss(to_onehot_y=True, softmax=True)
  optimizer = torch.optim.Adam(model.parameters(), 1e-4)
  dice_metric = DiceMetric(include_background=False, reduction="mean")

elif my_model=='RegUNet':
  device = torch.device("cuda:0")
  model = RegUNet(    
      spatial_dims=3,
      depth=2,
      in_channels=1,
      num_channel_initial = 16,
      out_channels=2,
      encode_kernel_sizes=3,
  ).to(device)
  loss_function = DiceLoss(to_onehot_y=True, softmax=True)
  optimizer = torch.optim.Adam(model.parameters(), 1e-4)
  dice_metric = DiceMetric(include_background=False, reduction="mean")

elif my_model=='SegResNet':
  device = torch.device("cuda:0")
  model = SegResNet(
      spatial_dims=3,
      in_channels=1,
      out_channels=2
  ).to(device)
  loss_function = DiceLoss(to_onehot_y=True, softmax=True)
  optimizer = torch.optim.Adam(model.parameters(), 1e-4)
  dice_metric = DiceMetric(include_background=False, reduction="mean")

else:
  print('No hay modelo')
# Out:
# /usr/local/lib/python3.7/dist-packages/monai/networks/nets/unet.py:136: UserWarning: `len(strides) > len(channels) - 1`, the last 1 values of strides will not be used.
#   warnings.warn(f"`len(strides) > len(channels) - 1`, the last {delta} values of strides will not be used.")

# %%
model
# Out:
# UNet(
#   (model): Sequential(
#     (0): ResidualUnit(
#       (conv): Sequential(
#         (unit0): Convolution(
#           (conv): Conv3d(1, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (adn): ADN(
#             (N): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (D): Dropout(p=0.0, inplace=False)
#             (A): PReLU(num_parameters=1)
#           )
#         )
#         (unit1): Convolution(
#           (conv): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (adn): ADN(
#             (N): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (D): Dropout(p=0.0, inplace=False)
#             (A): PReLU(num_parameters=1)
#           )
#         )
#       )
#       (residual): Conv3d(1, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#     )
#     (1): SkipConnection(
#       (submodule): Sequential(
#         (0): ResidualUnit(
#           (conv): Sequential(
#             (unit0): Convolution(
#               (conv): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#               (adn): ADN(
#                 (N): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (D): Dropout(p=0.0, inplace=False)
#                 (A): PReLU(num_parameters=1)
#               )
#             )
#             (unit1): Convolution(
#               (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (adn): ADN(
#                 (N): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (D): Dropout(p=0.0, inplace=False)
#                 (A): PReLU(num_parameters=1)
#               )
#             )
#           )
#           (residual): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#         )
#         (1): SkipConnection(
#           (submodule): Sequential(
#             (0): ResidualUnit(
#               (conv): Sequential(
#                 (unit0): Convolution(
#                   (conv): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                   (adn): ADN(
#                     (N): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (D): Dropout(p=0.0, inplace=False)
#                     (A): PReLU(num_parameters=1)
#                   )
#                 )
#                 (unit1): Convolution(
#                   (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#                   (adn): ADN(
#                     (N): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (D): Dropout(p=0.0, inplace=False)
#                     (A): PReLU(num_parameters=1)
#                   )
#                 )
#               )
#               (residual): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#             )
#             (1): SkipConnection(
#               (submodule): Sequential(
#                 (0): ResidualUnit(
#                   (conv): Sequential(
#                     (unit0): Convolution(
#                       (conv): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                       (adn): ADN(
#                         (N): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                         (D): Dropout(p=0.0, inplace=False)
#                         (A): PReLU(num_parameters=1)
#                       )
#                     )
#                     (unit1): Convolution(
#                       (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#                       (adn): ADN(
#                         (N): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                         (D): Dropout(p=0.0, inplace=False)
#                         (A): PReLU(num_parameters=1)
#                       )
#                     )
#                   )
#                   (residual): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                 )
#                 (1): SkipConnection(
#                   (submodule): Sequential(
#                     (0): ResidualUnit(
#                       (conv): Sequential(
#                         (unit0): Convolution(
#                           (conv): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                           (adn): ADN(
#                             (N): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                             (D): Dropout(p=0.0, inplace=False)
#                             (A): PReLU(num_parameters=1)
#                           )
#                         )
#                         (unit1): Convolution(
#                           (conv): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#                           (adn): ADN(
#                             (N): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                             (D): Dropout(p=0.0, inplace=False)
#                             (A): PReLU(num_parameters=1)
#                           )
#                         )
#                       )
#                       (residual): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                     )
#                     (1): SkipConnection(
#                       (submodule): ResidualUnit(
#                         (conv): Sequential(
#                           (unit0): Convolution(
#                             (conv): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#                             (adn): ADN(
#                               (N): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                               (D): Dropout(p=0.0, inplace=False)
#                               (A): PReLU(num_parameters=1)
#                             )
#                           )
#                           (unit1): Convolution(
#                             (conv): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#                             (adn): ADN(
#                               (N): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                               (D): Dropout(p=0.0, inplace=False)
#                               (A): PReLU(num_parameters=1)
#                             )
#                           )
#                         )
#                         (residual): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#                       )
#                     )
#                     (2): Sequential(
#                       (0): Convolution(
#                         (conv): ConvTranspose3d(768, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#                         (adn): ADN(
#                           (N): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                           (D): Dropout(p=0.0, inplace=False)
#                           (A): PReLU(num_parameters=1)
#                         )
#                       )
#                       (1): ResidualUnit(
#                         (conv): Sequential(
#                           (unit0): Convolution(
#                             (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#                             (adn): ADN(
#                               (N): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                               (D): Dropout(p=0.0, inplace=False)
#                               (A): PReLU(num_parameters=1)
#                             )
#                           )
#                         )
#                         (residual): Identity()
#                       )
#                     )
#                   )
#                 )
#                 (2): Sequential(
#                   (0): Convolution(
#                     (conv): ConvTranspose3d(256, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#                     (adn): ADN(
#                       (N): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                       (D): Dropout(p=0.0, inplace=False)
#                       (A): PReLU(num_parameters=1)
#                     )
#                   )
#                   (1): ResidualUnit(
#                     (conv): Sequential(
#                       (unit0): Convolution(
#                         (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#                         (adn): ADN(
#                           (N): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                           (D): Dropout(p=0.0, inplace=False)
#                           (A): PReLU(num_parameters=1)
#                         )
#                       )
#                     )
#                     (residual): Identity()
#                   )
#                 )
#               )
#             )
#             (2): Sequential(
#               (0): Convolution(
#                 (conv): ConvTranspose3d(128, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#                 (adn): ADN(
#                   (N): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (D): Dropout(p=0.0, inplace=False)
#                   (A): PReLU(num_parameters=1)
#                 )
#               )
#               (1): ResidualUnit(
#                 (conv): Sequential(
#                   (unit0): Convolution(
#                     (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#                     (adn): ADN(
#                       (N): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                       (D): Dropout(p=0.0, inplace=False)
#                       (A): PReLU(num_parameters=1)
#                     )
#                   )
#                 )
#                 (residual): Identity()
#               )
#             )
#           )
#         )
#         (2): Sequential(
#           (0): Convolution(
#             (conv): ConvTranspose3d(64, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#             (adn): ADN(
#               (N): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (D): Dropout(p=0.0, inplace=False)
#               (A): PReLU(num_parameters=1)
#             )
#           )
#           (1): ResidualUnit(
#             (conv): Sequential(
#               (unit0): Convolution(
#                 (conv): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#                 (adn): ADN(
#                   (N): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (D): Dropout(p=0.0, inplace=False)
#                   (A): PReLU(num_parameters=1)
#                 )
#               )
#             )
#             (residual): Identity()
#           )
#         )
#       )
#     )
#     (2): Sequential(
#       (0): Convolution(
#         (conv): ConvTranspose3d(32, 2, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#         (adn): ADN(
#           (N): BatchNorm3d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (D): Dropout(p=0.0, inplace=False)
#           (A): PReLU(num_parameters=1)
#         )
#       )
#       (1): ResidualUnit(
#         (conv): Sequential(
#           (unit0): Convolution(
#             (conv): Conv3d(2, 2, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           )
#         )
#         (residual): Identity()
#       )
#     )
#   )
# )

# %% [markdown]
# ## Execute a typical PyTorch training process

# %%
max_epochs = 200
val_interval = 2
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
metric_values = []
post_pred = Compose([EnsureType(), AsDiscrete(argmax=True, to_onehot=2)])
post_label = Compose([EnsureType(), AsDiscrete(to_onehot=2)])

for epoch in range(max_epochs):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        inputs, labels = (
            batch_data["image"].to(device),
            batch_data["label"].to(device),
        )
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        print(
            f"{step}/{len(train_ds) // train_loader.batch_size}, "
            f"train_loss: {loss.item():.4f}")
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_labels = (
                    val_data["image"].to(device),
                    val_data["label"].to(device),
                )
                roi_size = (160, 160, 160)
                sw_batch_size = 4
                val_outputs = sliding_window_inference(
                    val_inputs, roi_size, sw_batch_size, model)
                val_outputs = [post_pred(i) for i in decollate_batch(val_outputs)]
                val_labels = [post_label(i) for i in decollate_batch(val_labels)]
                # compute metric for current iteration
                dice_metric(y_pred=val_outputs, y=val_labels)

            # aggregate the final mean dice result
            metric = dice_metric.aggregate().item()
            # reset the status for next validation round
            dice_metric.reset()

            metric_values.append(metric)
            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), os.path.join(
                    root_dir, "best_metric_model.pth"))
                print("saved new best metric model")
            print(
                f"current epoch: {epoch + 1} current mean dice: {metric:.4f}"
                f"\nbest mean dice: {best_metric:.4f} "
                f"at epoch: {best_metric_epoch}"
            )
# Out:
# ----------
# epoch 1/200
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 1/16, train_loss: 0.6191
# 2/16, train_loss: 0.6328
# 3/16, train_loss: 0.6023
# 4/16, train_loss: 0.6185
# 5/16, train_loss: 0.6037
# 6/16, train_loss: 0.6247
# 7/16, train_loss: 0.6113
# 8/16, train_loss: 0.5929
# 9/16, train_loss: 0.6152
# 10/16, train_loss: 0.5809
# 11/16, train_loss: 0.6155
# 12/16, train_loss: 0.6149
# 13/16, train_loss: 0.5891
# 14/16, train_loss: 0.6194
# 15/16, train_loss: 0.5988
# 16/16, train_loss: 0.6112
# epoch 1 average loss: 0.6094
# ----------
# epoch 2/200
# 1/16, train_loss: 0.6021
# 2/16, train_loss: 0.5993
# 3/16, train_loss: 0.5838
# 4/16, train_loss: 0.5868
# 5/16, train_loss: 0.5865
# 6/16, train_loss: 0.6111
# 7/16, train_loss: 0.5911
# 8/16, train_loss: 0.6014
# 9/16, train_loss: 0.6119
# 10/16, train_loss: 0.5834
# 11/16, train_loss: 0.5897
# 12/16, train_loss: 0.6035
# 13/16, train_loss: 0.5530
# 14/16, train_loss: 0.5906
# 15/16, train_loss: 0.5802
# 16/16, train_loss: 0.5710
# epoch 2 average loss: 0.5904
# saved new best metric model
# current epoch: 2 current mean dice: 0.0441
# best mean dice: 0.0441 at epoch: 2
# ----------
# epoch 3/200
# 1/16, train_loss: 0.5837
# 2/16, train_loss: 0.5831
# 3/16, train_loss: 0.5847
# 4/16, train_loss: 0.5587
# 5/16, train_loss: 0.6078
# 6/16, train_loss: 0.5807
# 7/16, train_loss: 0.5847
# 8/16, train_loss: 0.5733
# 9/16, train_loss: 0.5646
# 10/16, train_loss: 0.5680
# 11/16, train_loss: 0.5762
# 12/16, train_loss: 0.5336
# 13/16, train_loss: 0.5988
# 14/16, train_loss: 0.5582
# 15/16, train_loss: 0.5708
# 16/16, train_loss: 0.5855
# epoch 3 average loss: 0.5758
# ----------
# epoch 4/200
# 1/16, train_loss: 0.5957
# 2/16, train_loss: 0.5759
# 3/16, train_loss: 0.5448
# 4/16, train_loss: 0.5557
# 5/16, train_loss: 0.5545
# 6/16, train_loss: 0.5748
# 7/16, train_loss: 0.5441
# 8/16, train_loss: 0.5862
# 9/16, train_loss: 0.5713
# 10/16, train_loss: 0.5322
# 11/16, train_loss: 0.5529
# 12/16, train_loss: 0.5675
# 13/16, train_loss: 0.5596
# 14/16, train_loss: 0.4996
# 15/16, train_loss: 0.5648
# 16/16, train_loss: 0.5451
# epoch 4 average loss: 0.5578
# saved new best metric model
# current epoch: 4 current mean dice: 0.0808
# best mean dice: 0.0808 at epoch: 4
# ----------
# epoch 5/200
# 1/16, train_loss: 0.5324
# 2/16, train_loss: 0.5362
# 3/16, train_loss: 0.5478
# 4/16, train_loss: 0.5290
# 5/16, train_loss: 0.5029
# 6/16, train_loss: 0.5669
# 7/16, train_loss: 0.5482
# 8/16, train_loss: 0.5581
# 9/16, train_loss: 0.5621
# 10/16, train_loss: 0.4974
# 11/16, train_loss: 0.5348
# 12/16, train_loss: 0.5171
# 13/16, train_loss: 0.5503
# 14/16, train_loss: 0.5253
# 15/16, train_loss: 0.5388
# 16/16, train_loss: 0.5314
# epoch 5 average loss: 0.5362
# ----------
# epoch 6/200
# 1/16, train_loss: 0.5629
# 2/16, train_loss: 0.5505
# 3/16, train_loss: 0.5257
# 4/16, train_loss: 0.5253
# 5/16, train_loss: 0.5176
# 6/16, train_loss: 0.5552
# 7/16, train_loss: 0.5505
# 8/16, train_loss: 0.5499
# 9/16, train_loss: 0.5079
# 10/16, train_loss: 0.5493
# 11/16, train_loss: 0.5305
# 12/16, train_loss: 0.4807
# 13/16, train_loss: 0.5142
# 14/16, train_loss: 0.5010
# 15/16, train_loss: 0.5396
# 16/16, train_loss: 0.5495
# epoch 6 average loss: 0.5319
# saved new best metric model
# current epoch: 6 current mean dice: 0.0848
# best mean dice: 0.0848 at epoch: 6
# ----------
# epoch 7/200
# 1/16, train_loss: 0.5447
# 2/16, train_loss: 0.5329
# 3/16, train_loss: 0.5516
# 4/16, train_loss: 0.5514
# 5/16, train_loss: 0.5677
# 6/16, train_loss: 0.5433
# 7/16, train_loss: 0.5306
# 8/16, train_loss: 0.5270
# 9/16, train_loss: 0.4927
# 10/16, train_loss: 0.5621
# 11/16, train_loss: 0.5174
# 12/16, train_loss: 0.5134
# 13/16, train_loss: 0.5177
# 14/16, train_loss: 0.5077
# 15/16, train_loss: 0.4973
# 16/16, train_loss: 0.5563
# epoch 7 average loss: 0.5321
# ----------
# epoch 8/200
# 1/16, train_loss: 0.5018
# 2/16, train_loss: 0.4836
# 3/16, train_loss: 0.5371
# 4/16, train_loss: 0.5474
# 5/16, train_loss: 0.5787
# 6/16, train_loss: 0.5323
# 7/16, train_loss: 0.5067
# 8/16, train_loss: 0.5101
# 9/16, train_loss: 0.4931
# 10/16, train_loss: 0.4881
# 11/16, train_loss: 0.5225
# 12/16, train_loss: 0.5521
# 13/16, train_loss: 0.4930
# 14/16, train_loss: 0.4931
# 15/16, train_loss: 0.5129
# 16/16, train_loss: 0.5101
# epoch 8 average loss: 0.5164
# saved new best metric model
# current epoch: 8 current mean dice: 0.1183
# best mean dice: 0.1183 at epoch: 8
# ----------
# epoch 9/200
# 1/16, train_loss: 0.4797
# 2/16, train_loss: 0.4973
# 3/16, train_loss: 0.4969
# 4/16, train_loss: 0.5261
# 5/16, train_loss: 0.4640
# 6/16, train_loss: 0.5068
# 7/16, train_loss: 0.4931
# 8/16, train_loss: 0.4605
# 9/16, train_loss: 0.5298
# 10/16, train_loss: 0.5002
# 11/16, train_loss: 0.5034
# 12/16, train_loss: 0.4946
# 13/16, train_loss: 0.5178
# 14/16, train_loss: 0.4338
# 15/16, train_loss: 0.4807
# 16/16, train_loss: 0.5559
# epoch 9 average loss: 0.4963
# ----------
# epoch 10/200
# 1/16, train_loss: 0.4967
# 2/16, train_loss: 0.5160
# 3/16, train_loss: 0.4530
# 4/16, train_loss: 0.5203
# 5/16, train_loss: 0.5012
# 6/16, train_loss: 0.5276
# 7/16, train_loss: 0.4811
# 8/16, train_loss: 0.4995
# 9/16, train_loss: 0.4388
# 10/16, train_loss: 0.4385
# 11/16, train_loss: 0.4959
# 12/16, train_loss: 0.4990
# 13/16, train_loss: 0.4429
# 14/16, train_loss: 0.4652
# 15/16, train_loss: 0.4880
# 16/16, train_loss: 0.5057
# epoch 10 average loss: 0.4856
# current epoch: 10 current mean dice: 0.1040
# best mean dice: 0.1183 at epoch: 8
# ----------
# epoch 11/200
# 1/16, train_loss: 0.4208
# 2/16, train_loss: 0.5062
# 3/16, train_loss: 0.4658
# 4/16, train_loss: 0.4766
# 5/16, train_loss: 0.4671
# 6/16, train_loss: 0.4840
# 7/16, train_loss: 0.5040
# 8/16, train_loss: 0.4875
# 9/16, train_loss: 0.4967
# 10/16, train_loss: 0.4393
# 11/16, train_loss: 0.4289
# 12/16, train_loss: 0.4466
# 13/16, train_loss: 0.4434
# 14/16, train_loss: 0.4445
# 15/16, train_loss: 0.4295
# 16/16, train_loss: 0.4915
# epoch 11 average loss: 0.4645
# ----------
# epoch 12/200
# 1/16, train_loss: 0.4641
# 2/16, train_loss: 0.4957
# 3/16, train_loss: 0.4633
# 4/16, train_loss: 0.4890
# 5/16, train_loss: 0.4567
# 6/16, train_loss: 0.4679
# 7/16, train_loss: 0.4642
# 8/16, train_loss: 0.4294
# 9/16, train_loss: 0.4082
# 10/16, train_loss: 0.4456
# 11/16, train_loss: 0.4706
# 12/16, train_loss: 0.4246
# 13/16, train_loss: 0.4544
# 14/16, train_loss: 0.4464
# 15/16, train_loss: 0.4320
# 16/16, train_loss: 0.4677
# epoch 12 average loss: 0.4550
# current epoch: 12 current mean dice: 0.0857
# best mean dice: 0.1183 at epoch: 8
# ----------
# epoch 13/200
# 1/16, train_loss: 0.4028
# 2/16, train_loss: 0.4967
# 3/16, train_loss: 0.4795
# 4/16, train_loss: 0.4630
# 5/16, train_loss: 0.4425
# 6/16, train_loss: 0.4823
# 7/16, train_loss: 0.4334
# 8/16, train_loss: 0.4973
# 9/16, train_loss: 0.4618
# 10/16, train_loss: 0.4635
# 11/16, train_loss: 0.4533
# 12/16, train_loss: 0.4691
# 13/16, train_loss: 0.4300
# 14/16, train_loss: 0.4479
# 15/16, train_loss: 0.4423
# 16/16, train_loss: 0.4185
# epoch 13 average loss: 0.4552
# ----------
# epoch 14/200
# 1/16, train_loss: 0.4247
# 2/16, train_loss: 0.4216
# 3/16, train_loss: 0.4972
# 4/16, train_loss: 0.4412
# 5/16, train_loss: 0.4136
# 6/16, train_loss: 0.4584
# 7/16, train_loss: 0.4371
# 8/16, train_loss: 0.4206
# 9/16, train_loss: 0.4167
# 10/16, train_loss: 0.4925
# 11/16, train_loss: 0.4338
# 12/16, train_loss: 0.4126
# 13/16, train_loss: 0.4632
# 14/16, train_loss: 0.3990
# 15/16, train_loss: 0.4122
# 16/16, train_loss: 0.4482
# epoch 14 average loss: 0.4370
# current epoch: 14 current mean dice: 0.0661
# best mean dice: 0.1183 at epoch: 8
# ----------
# epoch 15/200
# 1/16, train_loss: 0.3890
# 2/16, train_loss: 0.4109
# 3/16, train_loss: 0.4868
# 4/16, train_loss: 0.3843
# 5/16, train_loss: 0.3495
# 6/16, train_loss: 0.4954
# 7/16, train_loss: 0.5080
# 8/16, train_loss: 0.4474
# 9/16, train_loss: 0.4178
# 10/16, train_loss: 0.3733
# 11/16, train_loss: 0.4401
# 12/16, train_loss: 0.4181
# 13/16, train_loss: 0.4104
# 14/16, train_loss: 0.4525
# 15/16, train_loss: 0.4687
# 16/16, train_loss: 0.4057
# epoch 15 average loss: 0.4286
# ----------
# epoch 16/200
# 1/16, train_loss: 0.3858
# 2/16, train_loss: 0.3605
# 3/16, train_loss: 0.4620
# 4/16, train_loss: 0.4037
# 5/16, train_loss: 0.4766
# 6/16, train_loss: 0.3790
# 7/16, train_loss: 0.3452
# 8/16, train_loss: 0.4614
# 9/16, train_loss: 0.3638
# 10/16, train_loss: 0.3695
# 11/16, train_loss: 0.4803
# 12/16, train_loss: 0.3591
# 13/16, train_loss: 0.4072
# 14/16, train_loss: 0.4101
# 15/16, train_loss: 0.4511
# 16/16, train_loss: 0.4178
# epoch 16 average loss: 0.4083
# current epoch: 16 current mean dice: 0.0746
# best mean dice: 0.1183 at epoch: 8
# ----------
# epoch 17/200
# 1/16, train_loss: 0.3939
# 2/16, train_loss: 0.4147
# 3/16, train_loss: 0.4064
# 4/16, train_loss: 0.3358
# 5/16, train_loss: 0.4028
# 6/16, train_loss: 0.4530
# 7/16, train_loss: 0.4052
# 8/16, train_loss: 0.3902
# 9/16, train_loss: 0.3539
# 10/16, train_loss: 0.4330
# 11/16, train_loss: 0.4500
# 12/16, train_loss: 0.4131
# 13/16, train_loss: 0.4234
# 14/16, train_loss: 0.4114
# 15/16, train_loss: 0.3758
# 16/16, train_loss: 0.5284
# epoch 17 average loss: 0.4119
# ----------
# epoch 18/200
# 1/16, train_loss: 0.4259
# 2/16, train_loss: 0.3036
# 3/16, train_loss: 0.3774
# 4/16, train_loss: 0.3063
# 5/16, train_loss: 0.4964
# 6/16, train_loss: 0.3795
# 7/16, train_loss: 0.3630
# 8/16, train_loss: 0.4025
# 9/16, train_loss: 0.3936
# 10/16, train_loss: 0.3891
# 11/16, train_loss: 0.3803
# 12/16, train_loss: 0.5065
# 13/16, train_loss: 0.3979
# 14/16, train_loss: 0.3147
# 15/16, train_loss: 0.3971
# 16/16, train_loss: 0.3681
# epoch 18 average loss: 0.3876
# saved new best metric model
# current epoch: 18 current mean dice: 0.2234
# best mean dice: 0.2234 at epoch: 18
# ----------
# epoch 19/200
# 1/16, train_loss: 0.4042
# 2/16, train_loss: 0.3124
# 3/16, train_loss: 0.4195
# 4/16, train_loss: 0.4296
# 5/16, train_loss: 0.3258
# 6/16, train_loss: 0.3925
# 7/16, train_loss: 0.3494
# 8/16, train_loss: 0.3820
# 9/16, train_loss: 0.4212
# 10/16, train_loss: 0.3674
# 11/16, train_loss: 0.4323
# 12/16, train_loss: 0.4375
# 13/16, train_loss: 0.3943
# 14/16, train_loss: 0.4395
# 15/16, train_loss: 0.2928
# 16/16, train_loss: 0.3936
# epoch 19 average loss: 0.3871
# ----------
# epoch 20/200
# 1/16, train_loss: 0.3209
# 2/16, train_loss: 0.4075
# 3/16, train_loss: 0.4320
# 4/16, train_loss: 0.4210
# 5/16, train_loss: 0.4466
# 6/16, train_loss: 0.3118
# 7/16, train_loss: 0.3734
# 8/16, train_loss: 0.4991
# 9/16, train_loss: 0.3644
# 10/16, train_loss: 0.3342
# 11/16, train_loss: 0.4258
# 12/16, train_loss: 0.3272
# 13/16, train_loss: 0.3684
# 14/16, train_loss: 0.3579
# 15/16, train_loss: 0.4198
# 16/16, train_loss: 0.3218
# epoch 20 average loss: 0.3832
# current epoch: 20 current mean dice: 0.0899
# best mean dice: 0.2234 at epoch: 18
# ----------
# epoch 21/200
# 1/16, train_loss: 0.4126
# 2/16, train_loss: 0.3710
# 3/16, train_loss: 0.4293
# 4/16, train_loss: 0.4408
# 5/16, train_loss: 0.3862
# 6/16, train_loss: 0.3638
# 7/16, train_loss: 0.3292
# 8/16, train_loss: 0.3686
# 9/16, train_loss: 0.3354
# 10/16, train_loss: 0.4519
# 11/16, train_loss: 0.3530
# 12/16, train_loss: 0.2855
# 13/16, train_loss: 0.3612
# 14/16, train_loss: 0.3475
# 15/16, train_loss: 0.3138
# 16/16, train_loss: 0.4140
# epoch 21 average loss: 0.3727
# ----------
# epoch 22/200
# 1/16, train_loss: 0.3730
# 2/16, train_loss: 0.3472
# 3/16, train_loss: 0.4532
# 4/16, train_loss: 0.2915
# 5/16, train_loss: 0.4063
# 6/16, train_loss: 0.3143
# 7/16, train_loss: 0.3403
# 8/16, train_loss: 0.3578
# 9/16, train_loss: 0.4508
# 10/16, train_loss: 0.4246
# 11/16, train_loss: 0.2593
# 12/16, train_loss: 0.4000
# 13/16, train_loss: 0.4127
# 14/16, train_loss: 0.4385
# 15/16, train_loss: 0.3453
# 16/16, train_loss: 0.3943
# epoch 22 average loss: 0.3756
# saved new best metric model
# current epoch: 22 current mean dice: 0.4040
# best mean dice: 0.4040 at epoch: 22
# ----------
# epoch 23/200
# 1/16, train_loss: 0.4345
# 2/16, train_loss: 0.3885
# 3/16, train_loss: 0.3948
# 4/16, train_loss: 0.3638
# 5/16, train_loss: 0.2527
# 6/16, train_loss: 0.3869
# 7/16, train_loss: 0.4783
# 8/16, train_loss: 0.4518
# 9/16, train_loss: 0.3245
# 10/16, train_loss: 0.4333
# 11/16, train_loss: 0.2969
# 12/16, train_loss: 0.3863
# 13/16, train_loss: 0.3190
# 14/16, train_loss: 0.3249
# 15/16, train_loss: 0.4266
# 16/16, train_loss: 0.3976
# epoch 23 average loss: 0.3788
# ----------
# epoch 24/200
# 1/16, train_loss: 0.2952
# 2/16, train_loss: 0.3819
# 3/16, train_loss: 0.3764
# 4/16, train_loss: 0.2953
# 5/16, train_loss: 0.3530
# 6/16, train_loss: 0.3156
# 7/16, train_loss: 0.4105
# 8/16, train_loss: 0.3159
# 9/16, train_loss: 0.2775
# 10/16, train_loss: 0.4101
# 11/16, train_loss: 0.2932
# 12/16, train_loss: 0.3084
# 13/16, train_loss: 0.4056
# 14/16, train_loss: 0.3353
# 15/16, train_loss: 0.3301
# 16/16, train_loss: 0.3394
# epoch 24 average loss: 0.3402
# current epoch: 24 current mean dice: 0.0852
# best mean dice: 0.4040 at epoch: 22
# ----------
# epoch 25/200
# 1/16, train_loss: 0.3682
# 2/16, train_loss: 0.3079
# 3/16, train_loss: 0.3521
# 4/16, train_loss: 0.2956
# 5/16, train_loss: 0.3846
# 6/16, train_loss: 0.3528
# 7/16, train_loss: 0.3613
# 8/16, train_loss: 0.3491
# 9/16, train_loss: 0.4514
# 10/16, train_loss: 0.3938
# 11/16, train_loss: 0.4477
# 12/16, train_loss: 0.3470
# 13/16, train_loss: 0.3507
# 14/16, train_loss: 0.3540
# 15/16, train_loss: 0.3380
# 16/16, train_loss: 0.3886
# epoch 25 average loss: 0.3652
# ----------
# epoch 26/200
# 1/16, train_loss: 0.3746
# 2/16, train_loss: 0.3162
# 3/16, train_loss: 0.3451
# 4/16, train_loss: 0.3197
# 5/16, train_loss: 0.3266
# 6/16, train_loss: 0.3742
# 7/16, train_loss: 0.3733
# 8/16, train_loss: 0.2486
# 9/16, train_loss: 0.3108
# 10/16, train_loss: 0.3125
# 11/16, train_loss: 0.3308
# 12/16, train_loss: 0.3258
# 13/16, train_loss: 0.4188
# 14/16, train_loss: 0.3035
# 15/16, train_loss: 0.3636
# 16/16, train_loss: 0.3225
# epoch 26 average loss: 0.3354
# current epoch: 26 current mean dice: 0.0943
# best mean dice: 0.4040 at epoch: 22
# ----------
# epoch 27/200
# 1/16, train_loss: 0.2837
# 2/16, train_loss: 0.2836
# 3/16, train_loss: 0.3427
# 4/16, train_loss: 0.3089
# 5/16, train_loss: 0.3156
# 6/16, train_loss: 0.3048
# 7/16, train_loss: 0.3561
# 8/16, train_loss: 0.3125
# 9/16, train_loss: 0.2474
# 10/16, train_loss: 0.2824
# 11/16, train_loss: 0.3319
# 12/16, train_loss: 0.2721
# 13/16, train_loss: 0.3283
# 14/16, train_loss: 0.3276
# 15/16, train_loss: 0.3499
# 16/16, train_loss: 0.2662
# epoch 27 average loss: 0.3071
# ----------
# epoch 28/200
# 1/16, train_loss: 0.4827
# 2/16, train_loss: 0.3322
# 3/16, train_loss: 0.3966
# 4/16, train_loss: 0.3454
# 5/16, train_loss: 0.3193
# 6/16, train_loss: 0.4231
# 7/16, train_loss: 0.3527
# 8/16, train_loss: 0.3420
# 9/16, train_loss: 0.2766
# 10/16, train_loss: 0.3000
# 11/16, train_loss: 0.3917
# 12/16, train_loss: 0.2674
# 13/16, train_loss: 0.2493
# 14/16, train_loss: 0.3309
# 15/16, train_loss: 0.3332
# 16/16, train_loss: 0.3662
# epoch 28 average loss: 0.3443
# current epoch: 28 current mean dice: 0.2298
# best mean dice: 0.4040 at epoch: 22
# ----------
# epoch 29/200
# 1/16, train_loss: 0.2763
# 2/16, train_loss: 0.3300
# 3/16, train_loss: 0.3991
# 4/16, train_loss: 0.3481
# 5/16, train_loss: 0.3545
# 6/16, train_loss: 0.3388
# 7/16, train_loss: 0.3443
# 8/16, train_loss: 0.3550
# 9/16, train_loss: 0.3192
# 10/16, train_loss: 0.2835
# 11/16, train_loss: 0.3275
# 12/16, train_loss: 0.3568
# 13/16, train_loss: 0.3985
# 14/16, train_loss: 0.2721
# 15/16, train_loss: 0.3619
# 16/16, train_loss: 0.3290
# epoch 29 average loss: 0.3372
# ----------
# epoch 30/200
# 1/16, train_loss: 0.3751
# 2/16, train_loss: 0.3236
# 3/16, train_loss: 0.2758
# 4/16, train_loss: 0.3302
# 5/16, train_loss: 0.2983
# 6/16, train_loss: 0.3430
# 7/16, train_loss: 0.3315
# 8/16, train_loss: 0.2750
# 9/16, train_loss: 0.2969
# 10/16, train_loss: 0.3134
# 11/16, train_loss: 0.3567
# 12/16, train_loss: 0.2546
# 13/16, train_loss: 0.3585
# 14/16, train_loss: 0.3479
# 15/16, train_loss: 0.2825
# 16/16, train_loss: 0.3009
# epoch 30 average loss: 0.3165
# current epoch: 30 current mean dice: 0.1644
# best mean dice: 0.4040 at epoch: 22
# ----------
# epoch 31/200
# 1/16, train_loss: 0.3375
# 2/16, train_loss: 0.2606
# 3/16, train_loss: 0.2709
# 4/16, train_loss: 0.3025
# 5/16, train_loss: 0.3533
# 6/16, train_loss: 0.2476
# 7/16, train_loss: 0.3250
# 8/16, train_loss: 0.3061
# 9/16, train_loss: 0.1883
# 10/16, train_loss: 0.3381
# 11/16, train_loss: 0.2580
# 12/16, train_loss: 0.2903
# 13/16, train_loss: 0.2816
# 14/16, train_loss: 0.3503
# 15/16, train_loss: 0.2674
# 16/16, train_loss: 0.2924
# epoch 31 average loss: 0.2919
# ----------
# epoch 32/200
# 1/16, train_loss: 0.3035
# 2/16, train_loss: 0.3649
# 3/16, train_loss: 0.2043
# 4/16, train_loss: 0.2581
# 5/16, train_loss: 0.2616
# 6/16, train_loss: 0.2717
# 7/16, train_loss: 0.3515
# 8/16, train_loss: 0.3627
# 9/16, train_loss: 0.3328
# 10/16, train_loss: 0.2340
# 11/16, train_loss: 0.2598
# 12/16, train_loss: 0.2882
# 13/16, train_loss: 0.3088
# 14/16, train_loss: 0.3882
# 15/16, train_loss: 0.3914
# 16/16, train_loss: 0.3194
# epoch 32 average loss: 0.3063
# saved new best metric model
# current epoch: 32 current mean dice: 0.4301
# best mean dice: 0.4301 at epoch: 32
# ----------
# epoch 33/200
# 1/16, train_loss: 0.2689
# 2/16, train_loss: 0.3202
# 3/16, train_loss: 0.2471
# 4/16, train_loss: 0.3736
# 5/16, train_loss: 0.2887
# 6/16, train_loss: 0.3699
# 7/16, train_loss: 0.2757
# 8/16, train_loss: 0.2256
# 9/16, train_loss: 0.3218
# 10/16, train_loss: 0.2525
# 11/16, train_loss: 0.2737
# 12/16, train_loss: 0.3175
# 13/16, train_loss: 0.4280
# 14/16, train_loss: 0.2563
# 15/16, train_loss: 0.3653
# 16/16, train_loss: 0.2473
# epoch 33 average loss: 0.3020
# ----------
# epoch 34/200
# 1/16, train_loss: 0.4210
# 2/16, train_loss: 0.2561
# 3/16, train_loss: 0.3400
# 4/16, train_loss: 0.4662
# 5/16, train_loss: 0.3585
# 6/16, train_loss: 0.2251
# 7/16, train_loss: 0.2769
# 8/16, train_loss: 0.1693
# 9/16, train_loss: 0.2270
# 10/16, train_loss: 0.2752
# 11/16, train_loss: 0.3681
# 12/16, train_loss: 0.1686
# 13/16, train_loss: 0.3601
# 14/16, train_loss: 0.2627
# 15/16, train_loss: 0.3548
# 16/16, train_loss: 0.4276
# epoch 34 average loss: 0.3098
# current epoch: 34 current mean dice: 0.4247
# best mean dice: 0.4301 at epoch: 32
# ----------
# epoch 35/200
# 1/16, train_loss: 0.2633
# 2/16, train_loss: 0.2104
# 3/16, train_loss: 0.3271
# 4/16, train_loss: 0.3621
# 5/16, train_loss: 0.3017
# 6/16, train_loss: 0.3214
# 7/16, train_loss: 0.3547
# 8/16, train_loss: 0.3734
# 9/16, train_loss: 0.4127
# 10/16, train_loss: 0.4107
# 11/16, train_loss: 0.2548
# 12/16, train_loss: 0.2675
# 13/16, train_loss: 0.3220
# 14/16, train_loss: 0.2701
# 15/16, train_loss: 0.2132
# 16/16, train_loss: 0.3009
# epoch 35 average loss: 0.3104
# ----------
# epoch 36/200
# 1/16, train_loss: 0.2598
# 2/16, train_loss: 0.2581
# 3/16, train_loss: 0.3159
# 4/16, train_loss: 0.2878
# 5/16, train_loss: 0.2304
# 6/16, train_loss: 0.4128
# 7/16, train_loss: 0.3278
# 8/16, train_loss: 0.3306
# 9/16, train_loss: 0.3152
# 10/16, train_loss: 0.2906
# 11/16, train_loss: 0.2014
# 12/16, train_loss: 0.3562
# 13/16, train_loss: 0.2828
# 14/16, train_loss: 0.2532
# 15/16, train_loss: 0.2495
# 16/16, train_loss: 0.2022
# epoch 36 average loss: 0.2859
# saved new best metric model
# current epoch: 36 current mean dice: 0.7090
# best mean dice: 0.7090 at epoch: 36
# ----------
# epoch 37/200
# 1/16, train_loss: 0.2015
# 2/16, train_loss: 0.3086
# 3/16, train_loss: 0.2618
# 4/16, train_loss: 0.3517
# 5/16, train_loss: 0.2113
# 6/16, train_loss: 0.2935
# 7/16, train_loss: 0.3587
# 8/16, train_loss: 0.3164
# 9/16, train_loss: 0.2729
# 10/16, train_loss: 0.2462
# 11/16, train_loss: 0.3326
# 12/16, train_loss: 0.1711
# 13/16, train_loss: 0.2511
# 14/16, train_loss: 0.2664
# 15/16, train_loss: 0.3503
# 16/16, train_loss: 0.2854
# epoch 37 average loss: 0.2800
# ----------
# epoch 38/200
# 1/16, train_loss: 0.2446
# 2/16, train_loss: 0.2195
# 3/16, train_loss: 0.2586
# 4/16, train_loss: 0.2690
# 5/16, train_loss: 0.2501
# 6/16, train_loss: 0.2638
# 7/16, train_loss: 0.3601
# 8/16, train_loss: 0.3638
# 9/16, train_loss: 0.2344
# 10/16, train_loss: 0.3154
# 11/16, train_loss: 0.2989
# 12/16, train_loss: 0.3710
# 13/16, train_loss: 0.2049
# 14/16, train_loss: 0.2576
# 15/16, train_loss: 0.2764
# 16/16, train_loss: 0.3185
# epoch 38 average loss: 0.2817
# saved new best metric model
# current epoch: 38 current mean dice: 0.7619
# best mean dice: 0.7619 at epoch: 38
# ----------
# epoch 39/200
# 1/16, train_loss: 0.2430
# 2/16, train_loss: 0.1633
# 3/16, train_loss: 0.3494
# 4/16, train_loss: 0.2258
# 5/16, train_loss: 0.2928
# 6/16, train_loss: 0.2947
# 7/16, train_loss: 0.3541
# 8/16, train_loss: 0.2590
# 9/16, train_loss: 0.2533
# 10/16, train_loss: 0.2639
# 11/16, train_loss: 0.2778
# 12/16, train_loss: 0.3753
# 13/16, train_loss: 0.2644
# 14/16, train_loss: 0.2046
# 15/16, train_loss: 0.1832
# 16/16, train_loss: 0.2775
# epoch 39 average loss: 0.2676
# ----------
# epoch 40/200
# 1/16, train_loss: 0.2359
# 2/16, train_loss: 0.2515
# 3/16, train_loss: 0.2107
# 4/16, train_loss: 0.3146
# 5/16, train_loss: 0.2432
# 6/16, train_loss: 0.2630
# 7/16, train_loss: 0.3719
# 8/16, train_loss: 0.2640
# 9/16, train_loss: 0.3040
# 10/16, train_loss: 0.3545
# 11/16, train_loss: 0.3627
# 12/16, train_loss: 0.3512
# 13/16, train_loss: 0.2591
# 14/16, train_loss: 0.1972
# 15/16, train_loss: 0.1963
# 16/16, train_loss: 0.2795
# epoch 40 average loss: 0.2787
# saved new best metric model
# current epoch: 40 current mean dice: 0.7905
# best mean dice: 0.7905 at epoch: 40
# ----------
# epoch 41/200
# 1/16, train_loss: 0.2986
# 2/16, train_loss: 0.1921
# 3/16, train_loss: 0.1757
# 4/16, train_loss: 0.3186
# 5/16, train_loss: 0.2268
# 6/16, train_loss: 0.1890
# 7/16, train_loss: 0.2703
# 8/16, train_loss: 0.2673
# 9/16, train_loss: 0.1726
# 10/16, train_loss: 0.1420
# 11/16, train_loss: 0.3195
# 12/16, train_loss: 0.3089
# 13/16, train_loss: 0.2640
# 14/16, train_loss: 0.3482
# 15/16, train_loss: 0.2815
# 16/16, train_loss: 0.3559
# epoch 41 average loss: 0.2582
# ----------
# epoch 42/200
# 1/16, train_loss: 0.2238
# 2/16, train_loss: 0.3040
# 3/16, train_loss: 0.2298
# 4/16, train_loss: 0.3061
# 5/16, train_loss: 0.3050
# 6/16, train_loss: 0.3121
# 7/16, train_loss: 0.2649
# 8/16, train_loss: 0.2995
# 9/16, train_loss: 0.3041
# 10/16, train_loss: 0.3419
# 11/16, train_loss: 0.1571
# 12/16, train_loss: 0.1921
# 13/16, train_loss: 0.1452
# 14/16, train_loss: 0.2395
# 15/16, train_loss: 0.2383
# 16/16, train_loss: 0.3596
# epoch 42 average loss: 0.2639
# current epoch: 42 current mean dice: 0.6708
# best mean dice: 0.7905 at epoch: 40
# ----------
# epoch 43/200
# 1/16, train_loss: 0.1726
# 2/16, train_loss: 0.1677
# 3/16, train_loss: 0.2038
# 4/16, train_loss: 0.3542
# 5/16, train_loss: 0.2083
# 6/16, train_loss: 0.2285
# 7/16, train_loss: 0.2287
# 8/16, train_loss: 0.2896
# 9/16, train_loss: 0.1983
# 10/16, train_loss: 0.3702
# 11/16, train_loss: 0.2029
# 12/16, train_loss: 0.3125
# 13/16, train_loss: 0.3501
# 14/16, train_loss: 0.2820
# 15/16, train_loss: 0.3056
# 16/16, train_loss: 0.2586
# epoch 43 average loss: 0.2583
# ----------
# epoch 44/200
# 1/16, train_loss: 0.1864
# 2/16, train_loss: 0.2073
# 3/16, train_loss: 0.1842
# 4/16, train_loss: 0.2015
# 5/16, train_loss: 0.2412
# 6/16, train_loss: 0.2486
# 7/16, train_loss: 0.2975
# 8/16, train_loss: 0.3507
# 9/16, train_loss: 0.2542
# 10/16, train_loss: 0.1232
# 11/16, train_loss: 0.2286
# 12/16, train_loss: 0.3304
# 13/16, train_loss: 0.2499
# 14/16, train_loss: 0.2923
# 15/16, train_loss: 0.2388
# 16/16, train_loss: 0.1696
# epoch 44 average loss: 0.2378
# saved new best metric model
# current epoch: 44 current mean dice: 0.8179
# best mean dice: 0.8179 at epoch: 44
# ----------
# epoch 45/200
# 1/16, train_loss: 0.2910
# 2/16, train_loss: 0.2350
# 3/16, train_loss: 0.2402
# 4/16, train_loss: 0.3618
# 5/16, train_loss: 0.2872
# 6/16, train_loss: 0.1992
# 7/16, train_loss: 0.2921
# 8/16, train_loss: 0.4154
# 9/16, train_loss: 0.2356
# 10/16, train_loss: 0.2332
# 11/16, train_loss: 0.2243
# 12/16, train_loss: 0.3082
# 13/16, train_loss: 0.2637
# 14/16, train_loss: 0.2268
# 15/16, train_loss: 0.2526
# 16/16, train_loss: 0.2481
# epoch 45 average loss: 0.2696
# ----------
# epoch 46/200
# 1/16, train_loss: 0.2451
# 2/16, train_loss: 0.2438
# 3/16, train_loss: 0.1489
# 4/16, train_loss: 0.3053
# 5/16, train_loss: 0.2471
# 6/16, train_loss: 0.1823
# 7/16, train_loss: 0.2378
# 8/16, train_loss: 0.2140
# 9/16, train_loss: 0.2937
# 10/16, train_loss: 0.1892
# 11/16, train_loss: 0.3050
# 12/16, train_loss: 0.2047
# 13/16, train_loss: 0.2389
# 14/16, train_loss: 0.3561
# 15/16, train_loss: 0.3054
# 16/16, train_loss: 0.2914
# epoch 46 average loss: 0.2505
# current epoch: 46 current mean dice: 0.3608
# best mean dice: 0.8179 at epoch: 44
# ----------
# epoch 47/200
# 1/16, train_loss: 0.3421
# 2/16, train_loss: 0.3457
# 3/16, train_loss: 0.2967
# 4/16, train_loss: 0.2394
# 5/16, train_loss: 0.3116
# 6/16, train_loss: 0.2313
# 7/16, train_loss: 0.2905
# 8/16, train_loss: 0.2352
# 9/16, train_loss: 0.3055
# 10/16, train_loss: 0.3299
# 11/16, train_loss: 0.3420
# 12/16, train_loss: 0.2366
# 13/16, train_loss: 0.1920
# 14/16, train_loss: 0.3467
# 15/16, train_loss: 0.2422
# 16/16, train_loss: 0.2353
# epoch 47 average loss: 0.2827
# ----------
# epoch 48/200
# 1/16, train_loss: 0.1363
# 2/16, train_loss: 0.3969
# 3/16, train_loss: 0.2067
# 4/16, train_loss: 0.3537
# 5/16, train_loss: 0.2755
# 6/16, train_loss: 0.2143
# 7/16, train_loss: 0.2782
# 8/16, train_loss: 0.2478
# 9/16, train_loss: 0.2526
# 10/16, train_loss: 0.1828
# 11/16, train_loss: 0.3987
# 12/16, train_loss: 0.1912
# 13/16, train_loss: 0.3356
# 14/16, train_loss: 0.2605
# 15/16, train_loss: 0.2964
# 16/16, train_loss: 0.2563
# epoch 48 average loss: 0.2677
# saved new best metric model
# current epoch: 48 current mean dice: 0.8489
# best mean dice: 0.8489 at epoch: 48
# ----------
# epoch 49/200
# 1/16, train_loss: 0.1924
# 2/16, train_loss: 0.2339
# 3/16, train_loss: 0.2607
# 4/16, train_loss: 0.1500
# 5/16, train_loss: 0.2331
# 6/16, train_loss: 0.2024
# 7/16, train_loss: 0.3564
# 8/16, train_loss: 0.2726
# 9/16, train_loss: 0.3130
# 10/16, train_loss: 0.3651
# 11/16, train_loss: 0.1874
# 12/16, train_loss: 0.3161
# 13/16, train_loss: 0.2491
# 14/16, train_loss: 0.1662
# 15/16, train_loss: 0.2341
# 16/16, train_loss: 0.2856
# epoch 49 average loss: 0.2511
# ----------
# epoch 50/200
# 1/16, train_loss: 0.2815
# 2/16, train_loss: 0.3361
# 3/16, train_loss: 0.3428
# 4/16, train_loss: 0.2361
# 5/16, train_loss: 0.2569
# 6/16, train_loss: 0.1440
# 7/16, train_loss: 0.3990
# 8/16, train_loss: 0.1931
# 9/16, train_loss: 0.2570
# 10/16, train_loss: 0.2107
# 11/16, train_loss: 0.2579
# 12/16, train_loss: 0.1820
# 13/16, train_loss: 0.2866
# 14/16, train_loss: 0.3447
# 15/16, train_loss: 0.3026
# 16/16, train_loss: 0.1616
# epoch 50 average loss: 0.2620
# current epoch: 50 current mean dice: 0.4712
# best mean dice: 0.8489 at epoch: 48
# ----------
# epoch 51/200
# 1/16, train_loss: 0.1856
# 2/16, train_loss: 0.1578
# 3/16, train_loss: 0.2034
# 4/16, train_loss: 0.1995
# 5/16, train_loss: 0.2383
# 6/16, train_loss: 0.2210
# 7/16, train_loss: 0.4010
# 8/16, train_loss: 0.2055
# 9/16, train_loss: 0.2029
# 10/16, train_loss: 0.3465
# 11/16, train_loss: 0.2964
# 12/16, train_loss: 0.1898
# 13/16, train_loss: 0.1865
# 14/16, train_loss: 0.1858
# 15/16, train_loss: 0.2558
# 16/16, train_loss: 0.2280
# epoch 51 average loss: 0.2315
# ----------
# epoch 52/200
# 1/16, train_loss: 0.3253
# 2/16, train_loss: 0.1992
# 3/16, train_loss: 0.1315
# 4/16, train_loss: 0.2176
# 5/16, train_loss: 0.1231
# 6/16, train_loss: 0.1800
# 7/16, train_loss: 0.1778
# 8/16, train_loss: 0.2494
# 9/16, train_loss: 0.1247
# 10/16, train_loss: 0.2974
# 11/16, train_loss: 0.3983
# 12/16, train_loss: 0.3088
# 13/16, train_loss: 0.2407
# 14/16, train_loss: 0.1566
# 15/16, train_loss: 0.2018
# 16/16, train_loss: 0.1881
# epoch 52 average loss: 0.2200
# current epoch: 52 current mean dice: 0.4123
# best mean dice: 0.8489 at epoch: 48
# ----------
# epoch 53/200
# 1/16, train_loss: 0.2942
# 2/16, train_loss: 0.1977
# 3/16, train_loss: 0.2516
# 4/16, train_loss: 0.0958
# 5/16, train_loss: 0.3070
# 6/16, train_loss: 0.1736
# 7/16, train_loss: 0.0843
# 8/16, train_loss: 0.2555
# 9/16, train_loss: 0.1393
# 10/16, train_loss: 0.2791
# 11/16, train_loss: 0.1901
# 12/16, train_loss: 0.2507
# 13/16, train_loss: 0.2878
# 14/16, train_loss: 0.2369
# 15/16, train_loss: 0.1213
# 16/16, train_loss: 0.3990
# epoch 53 average loss: 0.2227
# ----------
# epoch 54/200
# 1/16, train_loss: 0.2267
# 2/16, train_loss: 0.2280
# 3/16, train_loss: 0.3288
# 4/16, train_loss: 0.2388
# 5/16, train_loss: 0.1911
# 6/16, train_loss: 0.3504
# 7/16, train_loss: 0.3438
# 8/16, train_loss: 0.2307
# 9/16, train_loss: 0.2681
# 10/16, train_loss: 0.1443
# 11/16, train_loss: 0.1166
# 12/16, train_loss: 0.1446
# 13/16, train_loss: 0.1864
# 14/16, train_loss: 0.2725
# 15/16, train_loss: 0.2320
# 16/16, train_loss: 0.3218
# epoch 54 average loss: 0.2390
# saved new best metric model
# current epoch: 54 current mean dice: 0.8751
# best mean dice: 0.8751 at epoch: 54
# ----------
# epoch 55/200
# 1/16, train_loss: 0.2573
# 2/16, train_loss: 0.3366
# 3/16, train_loss: 0.3987
# 4/16, train_loss: 0.1443
# 5/16, train_loss: 0.1842
# 6/16, train_loss: 0.2593
# 7/16, train_loss: 0.1510
# 8/16, train_loss: 0.2364
# 9/16, train_loss: 0.1168
# 10/16, train_loss: 0.2885
# 11/16, train_loss: 0.1113
# 12/16, train_loss: 0.2110
# 13/16, train_loss: 0.2541
# 14/16, train_loss: 0.1795
# 15/16, train_loss: 0.1308
# 16/16, train_loss: 0.2883
# epoch 55 average loss: 0.2218
# ----------
# epoch 56/200
# 1/16, train_loss: 0.3145
# 2/16, train_loss: 0.2247
# 3/16, train_loss: 0.1340
# 4/16, train_loss: 0.1789
# 5/16, train_loss: 0.2788
# 6/16, train_loss: 0.1680
# 7/16, train_loss: 0.0880
# 8/16, train_loss: 0.3441
# 9/16, train_loss: 0.2633
# 10/16, train_loss: 0.2885
# 11/16, train_loss: 0.2111
# 12/16, train_loss: 0.2735
# 13/16, train_loss: 0.2327
# 14/16, train_loss: 0.2286
# 15/16, train_loss: 0.1494
# 16/16, train_loss: 0.1309
# epoch 56 average loss: 0.2193
# saved new best metric model
# current epoch: 56 current mean dice: 0.8966
# best mean dice: 0.8966 at epoch: 56
# ----------
# epoch 57/200
# 1/16, train_loss: 0.2359
# 2/16, train_loss: 0.1779
# 3/16, train_loss: 0.2311
# 4/16, train_loss: 0.2312
# 5/16, train_loss: 0.1560
# 6/16, train_loss: 0.3383
# 7/16, train_loss: 0.2327
# 8/16, train_loss: 0.2864
# 9/16, train_loss: 0.1460
# 10/16, train_loss: 0.2259
# 11/16, train_loss: 0.2432
# 12/16, train_loss: 0.1878
# 13/16, train_loss: 0.3066
# 14/16, train_loss: 0.2281
# 15/16, train_loss: 0.2876
# 16/16, train_loss: 0.3446
# epoch 57 average loss: 0.2412
# ----------
# epoch 58/200
# 1/16, train_loss: 0.3476
# 2/16, train_loss: 0.2194
# 3/16, train_loss: 0.2432
# 4/16, train_loss: 0.1812
# 5/16, train_loss: 0.2253
# 6/16, train_loss: 0.1769
# 7/16, train_loss: 0.2890
# 8/16, train_loss: 0.2118
# 9/16, train_loss: 0.4020
# 10/16, train_loss: 0.1014
# 11/16, train_loss: 0.2946
# 12/16, train_loss: 0.2975
# 13/16, train_loss: 0.1193
# 14/16, train_loss: 0.1356
# 15/16, train_loss: 0.1463
# 16/16, train_loss: 0.1664
# epoch 58 average loss: 0.2223
# current epoch: 58 current mean dice: 0.6338
# best mean dice: 0.8966 at epoch: 56
# ----------
# epoch 59/200
# 1/16, train_loss: 0.1173
# 2/16, train_loss: 0.2334
# 3/16, train_loss: 0.2641
# 4/16, train_loss: 0.1825
# 5/16, train_loss: 0.2304
# 6/16, train_loss: 0.2204
# 7/16, train_loss: 0.2225
# 8/16, train_loss: 0.2129
# 9/16, train_loss: 0.3396
# 10/16, train_loss: 0.3165
# 11/16, train_loss: 0.1792
# 12/16, train_loss: 0.3458
# 13/16, train_loss: 0.3376
# 14/16, train_loss: 0.2813
# 15/16, train_loss: 0.2680
# 16/16, train_loss: 0.1348
# epoch 59 average loss: 0.2429
# ----------
# epoch 60/200
# 1/16, train_loss: 0.1917
# 2/16, train_loss: 0.1772
# 3/16, train_loss: 0.2768
# 4/16, train_loss: 0.2284
# 5/16, train_loss: 0.2873
# 6/16, train_loss: 0.4437
# 7/16, train_loss: 0.1705
# 8/16, train_loss: 0.1785
# 9/16, train_loss: 0.1741
# 10/16, train_loss: 0.3382
# 11/16, train_loss: 0.3193
# 12/16, train_loss: 0.2843
# 13/16, train_loss: 0.1775
# 14/16, train_loss: 0.1834
# 15/16, train_loss: 0.2286
# 16/16, train_loss: 0.1804
# epoch 60 average loss: 0.2400
# current epoch: 60 current mean dice: 0.7338
# best mean dice: 0.8966 at epoch: 56
# ----------
# epoch 61/200
# 1/16, train_loss: 0.2664
# 2/16, train_loss: 0.3484
# 3/16, train_loss: 0.2824
# 4/16, train_loss: 0.2870
# 5/16, train_loss: 0.1446
# 6/16, train_loss: 0.2270
# 7/16, train_loss: 0.2886
# 8/16, train_loss: 0.2278
# 9/16, train_loss: 0.1740
# 10/16, train_loss: 0.1740
# 11/16, train_loss: 0.3340
# 12/16, train_loss: 0.2076
# 13/16, train_loss: 0.1847
# 14/16, train_loss: 0.1357
# 15/16, train_loss: 0.3301
# 16/16, train_loss: 0.2244
# epoch 61 average loss: 0.2398
# ----------
# epoch 62/200
# 1/16, train_loss: 0.2326
# 2/16, train_loss: 0.3331
# 3/16, train_loss: 0.3938
# 4/16, train_loss: 0.3313
# 5/16, train_loss: 0.2206
# 6/16, train_loss: 0.2804
# 7/16, train_loss: 0.1698
# 8/16, train_loss: 0.1732
# 9/16, train_loss: 0.1073
# 10/16, train_loss: 0.1300
# 11/16, train_loss: 0.2608
# 12/16, train_loss: 0.2244
# 13/16, train_loss: 0.2257
# 14/16, train_loss: 0.2195
# 15/16, train_loss: 0.3910
# 16/16, train_loss: 0.1935
# epoch 62 average loss: 0.2429
# saved new best metric model
# current epoch: 62 current mean dice: 0.9105
# best mean dice: 0.9105 at epoch: 62
# ----------
# epoch 63/200
# 1/16, train_loss: 0.2323
# 2/16, train_loss: 0.3926
# 3/16, train_loss: 0.2278
# 4/16, train_loss: 0.2775
# 5/16, train_loss: 0.2918
# 6/16, train_loss: 0.1241
# 7/16, train_loss: 0.2233
# 8/16, train_loss: 0.1755
# 9/16, train_loss: 0.0799
# 10/16, train_loss: 0.2175
# 11/16, train_loss: 0.2149
# 12/16, train_loss: 0.2609
# 13/16, train_loss: 0.2800
# 14/16, train_loss: 0.3377
# 15/16, train_loss: 0.1813
# 16/16, train_loss: 0.2249
# epoch 63 average loss: 0.2339
# ----------
# epoch 64/200
# 1/16, train_loss: 0.2273
# 2/16, train_loss: 0.1323
# 3/16, train_loss: 0.2155
# 4/16, train_loss: 0.2288
# 5/16, train_loss: 0.2595
# 6/16, train_loss: 0.2389
# 7/16, train_loss: 0.2291
# 8/16, train_loss: 0.2266
# 9/16, train_loss: 0.3395
# 10/16, train_loss: 0.2198
# 11/16, train_loss: 0.2769
# 12/16, train_loss: 0.2194
# 13/16, train_loss: 0.3056
# 14/16, train_loss: 0.2604
# 15/16, train_loss: 0.1642
# 16/16, train_loss: 0.1706
# epoch 64 average loss: 0.2322
# current epoch: 64 current mean dice: 0.7487
# best mean dice: 0.9105 at epoch: 62
# ----------
# epoch 65/200
# 1/16, train_loss: 0.1684
# 2/16, train_loss: 0.2896
# 3/16, train_loss: 0.3235
# 4/16, train_loss: 0.2237
# 5/16, train_loss: 0.1287
# 6/16, train_loss: 0.2781
# 7/16, train_loss: 0.2150
# 8/16, train_loss: 0.1399
# 9/16, train_loss: 0.2702
# 10/16, train_loss: 0.2019
# 11/16, train_loss: 0.2225
# 12/16, train_loss: 0.1433
# 13/16, train_loss: 0.1784
# 14/16, train_loss: 0.2372
# 15/16, train_loss: 0.1820
# 16/16, train_loss: 0.2194
# epoch 65 average loss: 0.2139
# ----------
# epoch 66/200
# 1/16, train_loss: 0.2235
# 2/16, train_loss: 0.2207
# 3/16, train_loss: 0.2577
# 4/16, train_loss: 0.1952
# 5/16, train_loss: 0.3365
# 6/16, train_loss: 0.1839
# 7/16, train_loss: 0.1575
# 8/16, train_loss: 0.2379
# 9/16, train_loss: 0.2303
# 10/16, train_loss: 0.2173
# 11/16, train_loss: 0.1212
# 12/16, train_loss: 0.3363
# 13/16, train_loss: 0.1349
# 14/16, train_loss: 0.2774
# 15/16, train_loss: 0.1353
# 16/16, train_loss: 0.2379
# epoch 66 average loss: 0.2190
# current epoch: 66 current mean dice: 0.8270
# best mean dice: 0.9105 at epoch: 62
# ----------
# epoch 67/200
# 1/16, train_loss: 0.3408
# 2/16, train_loss: 0.2755
# 3/16, train_loss: 0.2860
# 4/16, train_loss: 0.3490
# 5/16, train_loss: 0.2442
# 6/16, train_loss: 0.2395
# 7/16, train_loss: 0.1990
# 8/16, train_loss: 0.2170
# 9/16, train_loss: 0.2542
# 10/16, train_loss: 0.1649
# 11/16, train_loss: 0.2253
# 12/16, train_loss: 0.1150
# 13/16, train_loss: 0.3925
# 14/16, train_loss: 0.3338
# 15/16, train_loss: 0.2879
# 16/16, train_loss: 0.1682
# epoch 67 average loss: 0.2558
# ----------
# epoch 68/200
# 1/16, train_loss: 0.2477
# 2/16, train_loss: 0.3933
# 3/16, train_loss: 0.2775
# 4/16, train_loss: 0.2189
# 5/16, train_loss: 0.1599
# 6/16, train_loss: 0.1839
# 7/16, train_loss: 0.2617
# 8/16, train_loss: 0.1663
# 9/16, train_loss: 0.2681
# 10/16, train_loss: 0.1797
# 11/16, train_loss: 0.2281
# 12/16, train_loss: 0.0630
# 13/16, train_loss: 0.1817
# 14/16, train_loss: 0.2242
# 15/16, train_loss: 0.2309
# 16/16, train_loss: 0.2111
# epoch 68 average loss: 0.2185
# current epoch: 68 current mean dice: 0.8864
# best mean dice: 0.9105 at epoch: 62
# ----------
# epoch 69/200
# 1/16, train_loss: 0.2804
# 2/16, train_loss: 0.1688
# 3/16, train_loss: 0.0875
# 4/16, train_loss: 0.2596
# 5/16, train_loss: 0.2730
# 6/16, train_loss: 0.3383
# 7/16, train_loss: 0.1068
# 8/16, train_loss: 0.1688
# 9/16, train_loss: 0.2729
# 10/16, train_loss: 0.2203
# 11/16, train_loss: 0.1297
# 12/16, train_loss: 0.2765
# 13/16, train_loss: 0.1745
# 14/16, train_loss: 0.2218
# 15/16, train_loss: 0.1772
# 16/16, train_loss: 0.2564
# epoch 69 average loss: 0.2133
# ----------
# epoch 70/200
# 1/16, train_loss: 0.2205
# 2/16, train_loss: 0.2332
# 3/16, train_loss: 0.1568
# 4/16, train_loss: 0.1154
# 5/16, train_loss: 0.3161
# 6/16, train_loss: 0.1176
# 7/16, train_loss: 0.3923
# 8/16, train_loss: 0.1105
# 9/16, train_loss: 0.1040
# 10/16, train_loss: 0.2600
# 11/16, train_loss: 0.2352
# 12/16, train_loss: 0.1750
# 13/16, train_loss: 0.2217
# 14/16, train_loss: 0.2619
# 15/16, train_loss: 0.1336
# 16/16, train_loss: 0.2530
# epoch 70 average loss: 0.2067
# current epoch: 70 current mean dice: 0.5735
# best mean dice: 0.9105 at epoch: 62
# ----------
# epoch 71/200
# 1/16, train_loss: 0.2815
# 2/16, train_loss: 0.2875
# 3/16, train_loss: 0.2316
# 4/16, train_loss: 0.2908
# 5/16, train_loss: 0.3913
# 6/16, train_loss: 0.2240
# 7/16, train_loss: 0.3486
# 8/16, train_loss: 0.1654
# 9/16, train_loss: 0.1643
# 10/16, train_loss: 0.1251
# 11/16, train_loss: 0.1636
# 12/16, train_loss: 0.1292
# 13/16, train_loss: 0.2190
# 14/16, train_loss: 0.1127
# 15/16, train_loss: 0.3429
# 16/16, train_loss: 0.1607
# epoch 71 average loss: 0.2274
# ----------
# epoch 72/200
# 1/16, train_loss: 0.2395
# 2/16, train_loss: 0.2800
# 3/16, train_loss: 0.2753
# 4/16, train_loss: 0.1579
# 5/16, train_loss: 0.1154
# 6/16, train_loss: 0.1316
# 7/16, train_loss: 0.2384
# 8/16, train_loss: 0.2315
# 9/16, train_loss: 0.1811
# 10/16, train_loss: 0.1355
# 11/16, train_loss: 0.1798
# 12/16, train_loss: 0.1667
# 13/16, train_loss: 0.3398
# 14/16, train_loss: 0.1578
# 15/16, train_loss: 0.1861
# 16/16, train_loss: 0.2746
# epoch 72 average loss: 0.2057
# current epoch: 72 current mean dice: 0.5916
# best mean dice: 0.9105 at epoch: 62
# ----------
# epoch 73/200
# 1/16, train_loss: 0.1771
# 2/16, train_loss: 0.2323
# 3/16, train_loss: 0.2259
# 4/16, train_loss: 0.2224
# 5/16, train_loss: 0.2147
# 6/16, train_loss: 0.2796
# 7/16, train_loss: 0.1673
# 8/16, train_loss: 0.1634
# 9/16, train_loss: 0.1400
# 10/16, train_loss: 0.1643
# 11/16, train_loss: 0.2706
# 12/16, train_loss: 0.1693
# 13/16, train_loss: 0.2713
# 14/16, train_loss: 0.1091
# 15/16, train_loss: 0.1238
# 16/16, train_loss: 0.2677
# epoch 73 average loss: 0.1999
# ----------
# epoch 74/200
# 1/16, train_loss: 0.1347
# 2/16, train_loss: 0.1702
# 3/16, train_loss: 0.3378
# 4/16, train_loss: 0.2536
# 5/16, train_loss: 0.1751
# 6/16, train_loss: 0.1213
# 7/16, train_loss: 0.2256
# 8/16, train_loss: 0.3320
# 9/16, train_loss: 0.2735
# 10/16, train_loss: 0.3882
# 11/16, train_loss: 0.1007
# 12/16, train_loss: 0.1508
# 13/16, train_loss: 0.2756
# 14/16, train_loss: 0.1606
# 15/16, train_loss: 0.3292
# 16/16, train_loss: 0.2190
# epoch 74 average loss: 0.2280
# current epoch: 74 current mean dice: 0.8751
# best mean dice: 0.9105 at epoch: 62
# ----------
# epoch 75/200
# 1/16, train_loss: 0.2848
# 2/16, train_loss: 0.2167
# 3/16, train_loss: 0.2683
# 4/16, train_loss: 0.1595
# 5/16, train_loss: 0.2301
# 6/16, train_loss: 0.3327
# 7/16, train_loss: 0.2223
# 8/16, train_loss: 0.2203
# 9/16, train_loss: 0.1395
# 10/16, train_loss: 0.2387
# 11/16, train_loss: 0.2165
# 12/16, train_loss: 0.2877
# 13/16, train_loss: 0.1669
# 14/16, train_loss: 0.2192
# 15/16, train_loss: 0.2006
# 16/16, train_loss: 0.3315
# epoch 75 average loss: 0.2335
# ----------
# epoch 76/200
# 1/16, train_loss: 0.3963
# 2/16, train_loss: 0.1266
# 3/16, train_loss: 0.3428
# 4/16, train_loss: 0.1052
# 5/16, train_loss: 0.3314
# 6/16, train_loss: 0.1582
# 7/16, train_loss: 0.2156
# 8/16, train_loss: 0.2276
# 9/16, train_loss: 0.2219
# 10/16, train_loss: 0.1390
# 11/16, train_loss: 0.2278
# 12/16, train_loss: 0.1088
# 13/16, train_loss: 0.2169
# 14/16, train_loss: 0.2769
# 15/16, train_loss: 0.2288
# 16/16, train_loss: 0.0523
# epoch 76 average loss: 0.2110
# current epoch: 76 current mean dice: 0.8019
# best mean dice: 0.9105 at epoch: 62
# ----------
# epoch 77/200
# 1/16, train_loss: 0.3303
# 2/16, train_loss: 0.2194
# 3/16, train_loss: 0.2453
# 4/16, train_loss: 0.1040
# 5/16, train_loss: 0.3447
# 6/16, train_loss: 0.2325
# 7/16, train_loss: 0.3730
# 8/16, train_loss: 0.2730
# 9/16, train_loss: 0.2739
# 10/16, train_loss: 0.1872
# 11/16, train_loss: 0.1162
# 12/16, train_loss: 0.1252
# 13/16, train_loss: 0.1783
# 14/16, train_loss: 0.1628
# 15/16, train_loss: 0.1633
# 16/16, train_loss: 0.1093
# epoch 77 average loss: 0.2149
# ----------
# epoch 78/200
# 1/16, train_loss: 0.1456
# 2/16, train_loss: 0.2112
# 3/16, train_loss: 0.1205
# 4/16, train_loss: 0.1191
# 5/16, train_loss: 0.1255
# 6/16, train_loss: 0.2166
# 7/16, train_loss: 0.2886
# 8/16, train_loss: 0.2681
# 9/16, train_loss: 0.1637
# 10/16, train_loss: 0.1636
# 11/16, train_loss: 0.2743
# 12/16, train_loss: 0.2769
# 13/16, train_loss: 0.0868
# 14/16, train_loss: 0.1027
# 15/16, train_loss: 0.2721
# 16/16, train_loss: 0.2513
# epoch 78 average loss: 0.1929
# current epoch: 78 current mean dice: 0.8565
# best mean dice: 0.9105 at epoch: 62
# ----------
# epoch 79/200
# 1/16, train_loss: 0.2271
# 2/16, train_loss: 0.1411
# 3/16, train_loss: 0.3157
# 4/16, train_loss: 0.1606
# 5/16, train_loss: 0.1035
# 6/16, train_loss: 0.3441
# 7/16, train_loss: 0.0544
# 8/16, train_loss: 0.1613
# 9/16, train_loss: 0.2802
# 10/16, train_loss: 0.2346
# 11/16, train_loss: 0.2220
# 12/16, train_loss: 0.2164
# 13/16, train_loss: 0.1671
# 14/16, train_loss: 0.1776
# 15/16, train_loss: 0.2741
# 16/16, train_loss: 0.1239
# epoch 79 average loss: 0.2002
# ----------
# epoch 80/200
# 1/16, train_loss: 0.2160
# 2/16, train_loss: 0.1534
# 3/16, train_loss: 0.2218
# 4/16, train_loss: 0.2212
# 5/16, train_loss: 0.2815
# 6/16, train_loss: 0.1126
# 7/16, train_loss: 0.1096
# 8/16, train_loss: 0.2163
# 9/16, train_loss: 0.2218
# 10/16, train_loss: 0.2604
# 11/16, train_loss: 0.2124
# 12/16, train_loss: 0.2081
# 13/16, train_loss: 0.1821
# 14/16, train_loss: 0.3393
# 15/16, train_loss: 0.3994
# 16/16, train_loss: 0.1280
# epoch 80 average loss: 0.2177
# current epoch: 80 current mean dice: 0.8884
# best mean dice: 0.9105 at epoch: 62
# ----------
# epoch 81/200
# 1/16, train_loss: 0.1544
# 2/16, train_loss: 0.3945
# 3/16, train_loss: 0.2130
# 4/16, train_loss: 0.1144
# 5/16, train_loss: 0.1185
# 6/16, train_loss: 0.3124
# 7/16, train_loss: 0.1602
# 8/16, train_loss: 0.3365
# 9/16, train_loss: 0.1053
# 10/16, train_loss: 0.0670
# 11/16, train_loss: 0.0959
# 12/16, train_loss: 0.2727
# 13/16, train_loss: 0.3433
# 14/16, train_loss: 0.1586
# 15/16, train_loss: 0.3287
# 16/16, train_loss: 0.1588
# epoch 81 average loss: 0.2084
# ----------
# epoch 82/200
# 1/16, train_loss: 0.2653
# 2/16, train_loss: 0.4295
# 3/16, train_loss: 0.2181
# 4/16, train_loss: 0.1717
# 5/16, train_loss: 0.1551
# 6/16, train_loss: 0.3087
# 7/16, train_loss: 0.2432
# 8/16, train_loss: 0.2958
# 9/16, train_loss: 0.3221
# 10/16, train_loss: 0.2209
# 11/16, train_loss: 0.2076
# 12/16, train_loss: 0.1483
# 13/16, train_loss: 0.2793
# 14/16, train_loss: 0.2788
# 15/16, train_loss: 0.2170
# 16/16, train_loss: 0.2870
# epoch 82 average loss: 0.2530
# current epoch: 82 current mean dice: 0.8874
# best mean dice: 0.9105 at epoch: 62
# ----------
# epoch 83/200
# 1/16, train_loss: 0.1272
# 2/16, train_loss: 0.1609
# 3/16, train_loss: 0.1615
# 4/16, train_loss: 0.2155
# 5/16, train_loss: 0.1111
# 6/16, train_loss: 0.1603
# 7/16, train_loss: 0.1060
# 8/16, train_loss: 0.3893
# 9/16, train_loss: 0.2133
# 10/16, train_loss: 0.2757
# 11/16, train_loss: 0.2644
# 12/16, train_loss: 0.3321
# 13/16, train_loss: 0.1634
# 14/16, train_loss: 0.2325
# 15/16, train_loss: 0.1876
# 16/16, train_loss: 0.2843
# epoch 83 average loss: 0.2116
# ----------
# epoch 84/200
# 1/16, train_loss: 0.0959
# 2/16, train_loss: 0.2299
# 3/16, train_loss: 0.2784
# 4/16, train_loss: 0.1025
# 5/16, train_loss: 0.2163
# 6/16, train_loss: 0.2231
# 7/16, train_loss: 0.0642
# 8/16, train_loss: 0.2129
# 9/16, train_loss: 0.3471
# 10/16, train_loss: 0.2174
# 11/16, train_loss: 0.1654
# 12/16, train_loss: 0.2837
# 13/16, train_loss: 0.1591
# 14/16, train_loss: 0.2902
# 15/16, train_loss: 0.1871
# 16/16, train_loss: 0.1347
# epoch 84 average loss: 0.2005
# current epoch: 84 current mean dice: 0.8310
# best mean dice: 0.9105 at epoch: 62
# ----------
# epoch 85/200
# 1/16, train_loss: 0.2712
# 2/16, train_loss: 0.1746
# 3/16, train_loss: 0.2045
# 4/16, train_loss: 0.2223
# 5/16, train_loss: 0.1616
# 6/16, train_loss: 0.2563
# 7/16, train_loss: 0.3201
# 8/16, train_loss: 0.1662
# 9/16, train_loss: 0.1743
# 10/16, train_loss: 0.3300
# 11/16, train_loss: 0.2143
# 12/16, train_loss: 0.1653
# 13/16, train_loss: 0.3306
# 14/16, train_loss: 0.1898
# 15/16, train_loss: 0.1583
# 16/16, train_loss: 0.1750
# epoch 85 average loss: 0.2197
# ----------
# epoch 86/200
# 1/16, train_loss: 0.1034
# 2/16, train_loss: 0.1564
# 3/16, train_loss: 0.1072
# 4/16, train_loss: 0.1585
# 5/16, train_loss: 0.3295
# 6/16, train_loss: 0.2149
# 7/16, train_loss: 0.2439
# 8/16, train_loss: 0.3295
# 9/16, train_loss: 0.1741
# 10/16, train_loss: 0.2410
# 11/16, train_loss: 0.0851
# 12/16, train_loss: 0.2144
# 13/16, train_loss: 0.1200
# 14/16, train_loss: 0.3075
# 15/16, train_loss: 0.3391
# 16/16, train_loss: 0.0468
# epoch 86 average loss: 0.1982
# current epoch: 86 current mean dice: 0.5339
# best mean dice: 0.9105 at epoch: 62
# ----------
# epoch 87/200
# 1/16, train_loss: 0.2804
# 2/16, train_loss: 0.1640
# 3/16, train_loss: 0.1030
# 4/16, train_loss: 0.2165
# 5/16, train_loss: 0.1606
# 6/16, train_loss: 0.2745
# 7/16, train_loss: 0.2712
# 8/16, train_loss: 0.1561
# 9/16, train_loss: 0.2765
# 10/16, train_loss: 0.1586
# 11/16, train_loss: 0.3015
# 12/16, train_loss: 0.3274
# 13/16, train_loss: 0.2375
# 14/16, train_loss: 0.3324
# 15/16, train_loss: 0.1082
# 16/16, train_loss: 0.3300
# epoch 87 average loss: 0.2312
# ----------
# epoch 88/200
# 1/16, train_loss: 0.2090
# 2/16, train_loss: 0.1703
# 3/16, train_loss: 0.3884
# 4/16, train_loss: 0.1594
# 5/16, train_loss: 0.1567
# 6/16, train_loss: 0.3348
# 7/16, train_loss: 0.1620
# 8/16, train_loss: 0.1710
# 9/16, train_loss: 0.1725
# 10/16, train_loss: 0.2618
# 11/16, train_loss: 0.1540
# 12/16, train_loss: 0.1643
# 13/16, train_loss: 0.2676
# 14/16, train_loss: 0.3274
# 15/16, train_loss: 0.2237
# 16/16, train_loss: 0.2164
# epoch 88 average loss: 0.2212
# saved new best metric model
# current epoch: 88 current mean dice: 0.9186
# best mean dice: 0.9186 at epoch: 88
# ----------
# epoch 89/200
# 1/16, train_loss: 0.1596
# 2/16, train_loss: 0.2124
# 3/16, train_loss: 0.0510
# 4/16, train_loss: 0.1590
# 5/16, train_loss: 0.3388
# 6/16, train_loss: 0.2738
# 7/16, train_loss: 0.2704
# 8/16, train_loss: 0.1543
# 9/16, train_loss: 0.1677
# 10/16, train_loss: 0.1611
# 11/16, train_loss: 0.3305
# 12/16, train_loss: 0.2684
# 13/16, train_loss: 0.0950
# 14/16, train_loss: 0.2198
# 15/16, train_loss: 0.2158
# 16/16, train_loss: 0.2449
# epoch 89 average loss: 0.2077
# ----------
# epoch 90/200
# 1/16, train_loss: 0.3343
# 2/16, train_loss: 0.2704
# 3/16, train_loss: 0.1694
# 4/16, train_loss: 0.1287
# 5/16, train_loss: 0.1472
# 6/16, train_loss: 0.2136
# 7/16, train_loss: 0.3870
# 8/16, train_loss: 0.2318
# 9/16, train_loss: 0.2650
# 10/16, train_loss: 0.1602
# 11/16, train_loss: 0.2770
# 12/16, train_loss: 0.1698
# 13/16, train_loss: 0.1626
# 14/16, train_loss: 0.1295
# 15/16, train_loss: 0.1448
# 16/16, train_loss: 0.2191
# epoch 90 average loss: 0.2131
# current epoch: 90 current mean dice: 0.5446
# best mean dice: 0.9186 at epoch: 88
# ----------
# epoch 91/200
# 1/16, train_loss: 0.1563
# 2/16, train_loss: 0.2669
# 3/16, train_loss: 0.2755
# 4/16, train_loss: 0.1662
# 5/16, train_loss: 0.1706
# 6/16, train_loss: 0.0489
# 7/16, train_loss: 0.3297
# 8/16, train_loss: 0.2303
# 9/16, train_loss: 0.2159
# 10/16, train_loss: 0.2233
# 11/16, train_loss: 0.1497
# 12/16, train_loss: 0.2775
# 13/16, train_loss: 0.2205
# 14/16, train_loss: 0.2695
# 15/16, train_loss: 0.2799
# 16/16, train_loss: 0.3336
# epoch 91 average loss: 0.2259
# ----------
# epoch 92/200
# 1/16, train_loss: 0.2140
# 2/16, train_loss: 0.2793
# 3/16, train_loss: 0.2827
# 4/16, train_loss: 0.1577
# 5/16, train_loss: 0.2208
# 6/16, train_loss: 0.2152
# 7/16, train_loss: 0.3160
# 8/16, train_loss: 0.2114
# 9/16, train_loss: 0.3864
# 10/16, train_loss: 0.3390
# 11/16, train_loss: 0.1661
# 12/16, train_loss: 0.1204
# 13/16, train_loss: 0.0542
# 14/16, train_loss: 0.3301
# 15/16, train_loss: 0.1628
# 16/16, train_loss: 0.2729
# epoch 92 average loss: 0.2331
# current epoch: 92 current mean dice: 0.8278
# best mean dice: 0.9186 at epoch: 88
# ----------
# epoch 93/200
# 1/16, train_loss: 0.1227
# 2/16, train_loss: 0.2402
# 3/16, train_loss: 0.3177
# 4/16, train_loss: 0.1122
# 5/16, train_loss: 0.1637
# 6/16, train_loss: 0.0980
# 7/16, train_loss: 0.2815
# 8/16, train_loss: 0.2291
# 9/16, train_loss: 0.3291
# 10/16, train_loss: 0.1814
# 11/16, train_loss: 0.2688
# 12/16, train_loss: 0.2202
# 13/16, train_loss: 0.2117
# 14/16, train_loss: 0.1157
# 15/16, train_loss: 0.1089
# 16/16, train_loss: 0.1516
# epoch 93 average loss: 0.1970
# ----------
# epoch 94/200
# 1/16, train_loss: 0.2534
# 2/16, train_loss: 0.2147
# 3/16, train_loss: 0.0848
# 4/16, train_loss: 0.2041
# 5/16, train_loss: 0.2207
# 6/16, train_loss: 0.1175
# 7/16, train_loss: 0.2336
# 8/16, train_loss: 0.2807
# 9/16, train_loss: 0.2164
# 10/16, train_loss: 0.2700
# 11/16, train_loss: 0.0537
# 12/16, train_loss: 0.1654
# 13/16, train_loss: 0.3238
# 14/16, train_loss: 0.1966
# 15/16, train_loss: 0.3325
# 16/16, train_loss: 0.0720
# epoch 94 average loss: 0.2025
# current epoch: 94 current mean dice: 0.9142
# best mean dice: 0.9186 at epoch: 88
# ----------
# epoch 95/200
# ...
# 8/16, train_loss: 0.1534
# 9/16, train_loss: 0.1588
# 10/16, train_loss: 0.0541
# 11/16, train_loss: 0.3236
# 12/16, train_loss: 0.0924
# 13/16, train_loss: 0.3245
# 14/16, train_loss: 0.2113
# 15/16, train_loss: 0.1471
# 16/16, train_loss: 0.2607
# epoch 169 average loss: 0.2053
# ----------
# epoch 170/200
# 1/16, train_loss: 0.3266
# 2/16, train_loss: 0.2113
# 3/16, train_loss: 0.2093
# 4/16, train_loss: 0.1514
# 5/16, train_loss: 0.0945
# 6/16, train_loss: 0.0985
# 7/16, train_loss: 0.1728
# 8/16, train_loss: 0.2778
# 9/16, train_loss: 0.2694
# 10/16, train_loss: 0.1580
# 11/16, train_loss: 0.2108
# 12/16, train_loss: 0.1489
# 13/16, train_loss: 0.1765
# 14/16, train_loss: 0.2644
# 15/16, train_loss: 0.2646
# 16/16, train_loss: 0.1588
# epoch 170 average loss: 0.1996
# current epoch: 170 current mean dice: 0.8941
# best mean dice: 0.9306 at epoch: 164
# ----------
# epoch 171/200
# 1/16, train_loss: 0.1458
# 2/16, train_loss: 0.2920
# 3/16, train_loss: 0.2664
# 4/16, train_loss: 0.0862
# 5/16, train_loss: 0.3260
# 6/16, train_loss: 0.1475
# 7/16, train_loss: 0.1562
# 8/16, train_loss: 0.1507
# 9/16, train_loss: 0.1587
# 10/16, train_loss: 0.1975
# 11/16, train_loss: 0.1446
# 12/16, train_loss: 0.0893
# 13/16, train_loss: 0.2128
# 14/16, train_loss: 0.2034
# 15/16, train_loss: 0.1632
# 16/16, train_loss: 0.2046
# epoch 171 average loss: 0.1841
# ----------
# epoch 172/200
# 1/16, train_loss: 0.2070
# 2/16, train_loss: 0.1741
# 3/16, train_loss: 0.0884
# 4/16, train_loss: 0.2686
# 5/16, train_loss: 0.1429
# 6/16, train_loss: 0.2057
# 7/16, train_loss: 0.0945
# 8/16, train_loss: 0.2651
# 9/16, train_loss: 0.1452
# 10/16, train_loss: 0.2100
# 11/16, train_loss: 0.4457
# 12/16, train_loss: 0.1939
# 13/16, train_loss: 0.2749
# 14/16, train_loss: 0.2717
# 15/16, train_loss: 0.2029
# 16/16, train_loss: 0.1197
# epoch 172 average loss: 0.2069
# saved new best metric model
# current epoch: 172 current mean dice: 0.9306
# best mean dice: 0.9306 at epoch: 172
# ----------
# epoch 173/200
# 1/16, train_loss: 0.1449
# 2/16, train_loss: 0.0910
# 3/16, train_loss: 0.2204
# 4/16, train_loss: 0.0991
# 5/16, train_loss: 0.0884
# 6/16, train_loss: 0.1485
# 7/16, train_loss: 0.1508
# 8/16, train_loss: 0.1526
# 9/16, train_loss: 0.3859
# 10/16, train_loss: 0.1297
# 11/16, train_loss: 0.2644
# 12/16, train_loss: 0.2063
# 13/16, train_loss: 0.1473
# 14/16, train_loss: 0.1508
# 15/16, train_loss: 0.2087
# 16/16, train_loss: 0.0878
# epoch 173 average loss: 0.1673
# ----------
# epoch 174/200
# 1/16, train_loss: 0.4127
# 2/16, train_loss: 0.1517
# 3/16, train_loss: 0.2075
# 4/16, train_loss: 0.1634
# 5/16, train_loss: 0.1563
# 6/16, train_loss: 0.0919
# 7/16, train_loss: 0.2048
# 8/16, train_loss: 0.1467
# 9/16, train_loss: 0.2044
# 10/16, train_loss: 0.1276
# 11/16, train_loss: 0.3274
# 12/16, train_loss: 0.2645
# 13/16, train_loss: 0.1560
# 14/16, train_loss: 0.2713
# 15/16, train_loss: 0.1647
# 16/16, train_loss: 0.3143
# epoch 174 average loss: 0.2103
# saved new best metric model
# current epoch: 174 current mean dice: 0.9351
# best mean dice: 0.9351 at epoch: 174
# ----------
# epoch 175/200
# 1/16, train_loss: 0.2800
# 2/16, train_loss: 0.1500
# 3/16, train_loss: 0.2844
# 4/16, train_loss: 0.2694
# 5/16, train_loss: 0.2135
# 6/16, train_loss: 0.1511
# 7/16, train_loss: 0.3421
# 8/16, train_loss: 0.2052
# 9/16, train_loss: 0.2086
# 10/16, train_loss: 0.2033
# 11/16, train_loss: 0.2609
# 12/16, train_loss: 0.2063
# 13/16, train_loss: 0.1792
# 14/16, train_loss: 0.2631
# 15/16, train_loss: 0.0876
# 16/16, train_loss: 0.2615
# epoch 175 average loss: 0.2229
# ----------
# epoch 176/200
# 1/16, train_loss: 0.3282
# 2/16, train_loss: 0.0937
# 3/16, train_loss: 0.2742
# 4/16, train_loss: 0.1137
# 5/16, train_loss: 0.0279
# 6/16, train_loss: 0.2039
# 7/16, train_loss: 0.2170
# 8/16, train_loss: 0.1579
# 9/16, train_loss: 0.3052
# 10/16, train_loss: 0.3251
# 11/16, train_loss: 0.0893
# 12/16, train_loss: 0.2122
# 13/16, train_loss: 0.1702
# 14/16, train_loss: 0.1529
# 15/16, train_loss: 0.2174
# 16/16, train_loss: 0.0932
# epoch 176 average loss: 0.1864
# current epoch: 176 current mean dice: 0.9121
# best mean dice: 0.9351 at epoch: 174
# ----------
# epoch 177/200
# 1/16, train_loss: 0.2655
# 2/16, train_loss: 0.0901
# 3/16, train_loss: 0.2072
# 4/16, train_loss: 0.1572
# 5/16, train_loss: 0.1513
# 6/16, train_loss: 0.1300
# 7/16, train_loss: 0.1450
# 8/16, train_loss: 0.2164
# 9/16, train_loss: 0.2041
# 10/16, train_loss: 0.1280
# 11/16, train_loss: 0.1447
# 12/16, train_loss: 0.2681
# 13/16, train_loss: 0.2104
# 14/16, train_loss: 0.2731
# 15/16, train_loss: 0.2717
# 16/16, train_loss: 0.0930
# epoch 177 average loss: 0.1847
# ----------
# epoch 178/200
# 1/16, train_loss: 0.2040
# 2/16, train_loss: 0.0876
# 3/16, train_loss: 0.1568
# 4/16, train_loss: 0.0883
# 5/16, train_loss: 0.2077
# 6/16, train_loss: 0.2041
# 7/16, train_loss: 0.1538
# 8/16, train_loss: 0.0357
# 9/16, train_loss: 0.2396
# 10/16, train_loss: 0.1441
# 11/16, train_loss: 0.1641
# 12/16, train_loss: 0.1025
# 13/16, train_loss: 0.2657
# 14/16, train_loss: 0.1488
# 15/16, train_loss: 0.2662
# 16/16, train_loss: 0.2737
# epoch 178 average loss: 0.1714
# current epoch: 178 current mean dice: 0.9148
# best mean dice: 0.9351 at epoch: 174
# ----------
# epoch 179/200
# 1/16, train_loss: 0.2650
# 2/16, train_loss: 0.3325
# 3/16, train_loss: 0.2676
# 4/16, train_loss: 0.0886
# 5/16, train_loss: 0.2917
# 6/16, train_loss: 0.2655
# 7/16, train_loss: 0.2042
# 8/16, train_loss: 0.3417
# 9/16, train_loss: 0.0439
# 10/16, train_loss: 0.1717
# 11/16, train_loss: 0.2070
# 12/16, train_loss: 0.0887
# 13/16, train_loss: 0.2089
# 14/16, train_loss: 0.1330
# 15/16, train_loss: 0.2192
# 16/16, train_loss: 0.1734
# epoch 179 average loss: 0.2064
# ----------
# epoch 180/200
# 1/16, train_loss: 0.3291
# 2/16, train_loss: 0.0317
# 3/16, train_loss: 0.0841
# 4/16, train_loss: 0.2621
# 5/16, train_loss: 0.1461
# 6/16, train_loss: 0.1511
# 7/16, train_loss: 0.1528
# 8/16, train_loss: 0.0278
# 9/16, train_loss: 0.3130
# 10/16, train_loss: 0.1623
# 11/16, train_loss: 0.2095
# 12/16, train_loss: 0.2366
# 13/16, train_loss: 0.1428
# 14/16, train_loss: 0.2771
# 15/16, train_loss: 0.2153
# 16/16, train_loss: 0.1441
# epoch 180 average loss: 0.1804
# current epoch: 180 current mean dice: 0.9291
# best mean dice: 0.9351 at epoch: 174
# ----------
# epoch 181/200
# 1/16, train_loss: 0.1487
# 2/16, train_loss: 0.1499
# 3/16, train_loss: 0.0893
# 4/16, train_loss: 0.2116
# 5/16, train_loss: 0.2070
# 6/16, train_loss: 0.3255
# 7/16, train_loss: 0.3246
# 8/16, train_loss: 0.1464
# 9/16, train_loss: 0.1405
# 10/16, train_loss: 0.1849
# 11/16, train_loss: 0.1886
# 12/16, train_loss: 0.2648
# 13/16, train_loss: 0.2613
# 14/16, train_loss: 0.2025
# 15/16, train_loss: 0.2119
# 16/16, train_loss: 0.3238
# epoch 181 average loss: 0.2113
# ----------
# epoch 182/200
# 1/16, train_loss: 0.1401
# 2/16, train_loss: 0.1447
# 3/16, train_loss: 0.2189
# 4/16, train_loss: 0.2608
# 5/16, train_loss: 0.3240
# 6/16, train_loss: 0.0377
# 7/16, train_loss: 0.1470
# 8/16, train_loss: 0.2047
# 9/16, train_loss: 0.2041
# 10/16, train_loss: 0.0844
# 11/16, train_loss: 0.2072
# 12/16, train_loss: 0.2614
# 13/16, train_loss: 0.1578
# 14/16, train_loss: 0.0871
# 15/16, train_loss: 0.2395
# 16/16, train_loss: 0.0828
# epoch 182 average loss: 0.1751
# current epoch: 182 current mean dice: 0.9329
# best mean dice: 0.9351 at epoch: 174
# ----------
# epoch 183/200
# 1/16, train_loss: 0.3230
# 2/16, train_loss: 0.2582
# 3/16, train_loss: 0.2076
# 4/16, train_loss: 0.1067
# 5/16, train_loss: 0.0905
# 6/16, train_loss: 0.3242
# 7/16, train_loss: 0.0854
# 8/16, train_loss: 0.1681
# 9/16, train_loss: 0.0888
# 10/16, train_loss: 0.2670
# 11/16, train_loss: 0.2031
# 12/16, train_loss: 0.2023
# 13/16, train_loss: 0.1483
# 14/16, train_loss: 0.2113
# 15/16, train_loss: 0.2101
# 16/16, train_loss: 0.0859
# epoch 183 average loss: 0.1863
# ----------
# epoch 184/200
# 1/16, train_loss: 0.1447
# 2/16, train_loss: 0.2633
# 3/16, train_loss: 0.2685
# 4/16, train_loss: 0.2677
# 5/16, train_loss: 0.0315
# 6/16, train_loss: 0.0882
# 7/16, train_loss: 0.1773
# 8/16, train_loss: 0.0473
# 9/16, train_loss: 0.2653
# 10/16, train_loss: 0.3056
# 11/16, train_loss: 0.1596
# 12/16, train_loss: 0.0291
# 13/16, train_loss: 0.2029
# 14/16, train_loss: 0.1567
# 15/16, train_loss: 0.2615
# 16/16, train_loss: 0.1616
# epoch 184 average loss: 0.1769
# current epoch: 184 current mean dice: 0.9103
# best mean dice: 0.9351 at epoch: 174
# ----------
# epoch 185/200
# 1/16, train_loss: 0.1603
# 2/16, train_loss: 0.0888
# 3/16, train_loss: 0.2645
# 4/16, train_loss: 0.0814
# 5/16, train_loss: 0.2754
# 6/16, train_loss: 0.2325
# 7/16, train_loss: 0.1535
# 8/16, train_loss: 0.2085
# 9/16, train_loss: 0.1505
# 10/16, train_loss: 0.2654
# 11/16, train_loss: 0.1528
# 12/16, train_loss: 0.2628
# 13/16, train_loss: 0.2652
# 14/16, train_loss: 0.1424
# 15/16, train_loss: 0.3238
# 16/16, train_loss: 0.2620
# epoch 185 average loss: 0.2056
# ----------
# epoch 186/200
# 1/16, train_loss: 0.1450
# 2/16, train_loss: 0.1389
# 3/16, train_loss: 0.1108
# 4/16, train_loss: 0.0847
# 5/16, train_loss: 0.2105
# 6/16, train_loss: 0.2072
# 7/16, train_loss: 0.3291
# 8/16, train_loss: 0.3846
# 9/16, train_loss: 0.2082
# 10/16, train_loss: 0.1451
# 11/16, train_loss: 0.2642
# 12/16, train_loss: 0.1544
# 13/16, train_loss: 0.2727
# 14/16, train_loss: 0.2219
# 15/16, train_loss: 0.1491
# 16/16, train_loss: 0.0917
# epoch 186 average loss: 0.1949
# current epoch: 186 current mean dice: 0.9214
# best mean dice: 0.9351 at epoch: 174
# ----------
# epoch 187/200
# 1/16, train_loss: 0.2096
# 2/16, train_loss: 0.1061
# 3/16, train_loss: 0.2045
# 4/16, train_loss: 0.1507
# 5/16, train_loss: 0.1853
# 6/16, train_loss: 0.2215
# 7/16, train_loss: 0.2695
# 8/16, train_loss: 0.2641
# 9/16, train_loss: 0.1467
# 10/16, train_loss: 0.1482
# 11/16, train_loss: 0.0821
# 12/16, train_loss: 0.2586
# 13/16, train_loss: 0.0851
# 14/16, train_loss: 0.2686
# 15/16, train_loss: 0.1807
# 16/16, train_loss: 0.0865
# epoch 187 average loss: 0.1792
# ----------
# epoch 188/200
# 1/16, train_loss: 0.0859
# 2/16, train_loss: 0.2634
# 3/16, train_loss: 0.1529
# 4/16, train_loss: 0.2657
# 5/16, train_loss: 0.0859
# 6/16, train_loss: 0.0916
# 7/16, train_loss: 0.2086
# 8/16, train_loss: 0.0836
# 9/16, train_loss: 0.2719
# 10/16, train_loss: 0.2620
# 11/16, train_loss: 0.3225
# 12/16, train_loss: 0.3225
# 13/16, train_loss: 0.2690
# 14/16, train_loss: 0.1480
# 15/16, train_loss: 0.1478
# 16/16, train_loss: 0.1533
# epoch 188 average loss: 0.1959
# current epoch: 188 current mean dice: 0.9346
# best mean dice: 0.9351 at epoch: 174
# ----------
# epoch 189/200
# 1/16, train_loss: 0.2173
# 2/16, train_loss: 0.2722
# 3/16, train_loss: 0.1630
# 4/16, train_loss: 0.2052
# 5/16, train_loss: 0.0842
# 6/16, train_loss: 0.2101
# 7/16, train_loss: 0.0849
# 8/16, train_loss: 0.2541
# 9/16, train_loss: 0.1402
# 10/16, train_loss: 0.1785
# 11/16, train_loss: 0.2060
# 12/16, train_loss: 0.2702
# 13/16, train_loss: 0.2650
# 14/16, train_loss: 0.2720
# 15/16, train_loss: 0.0833
# 16/16, train_loss: 0.2514
# epoch 189 average loss: 0.1973
# ----------
# epoch 190/200
# 1/16, train_loss: 0.2648
# 2/16, train_loss: 0.0802
# 3/16, train_loss: 0.2626
# 4/16, train_loss: 0.2028
# 5/16, train_loss: 0.3845
# 6/16, train_loss: 0.3229
# 7/16, train_loss: 0.2623
# 8/16, train_loss: 0.2096
# 9/16, train_loss: 0.1440
# 10/16, train_loss: 0.1547
# 11/16, train_loss: 0.1521
# 12/16, train_loss: 0.2070
# 13/16, train_loss: 0.1415
# 14/16, train_loss: 0.1541
# 15/16, train_loss: 0.2052
# 16/16, train_loss: 0.1483
# epoch 190 average loss: 0.2060
# current epoch: 190 current mean dice: 0.9293
# best mean dice: 0.9351 at epoch: 174
# ----------
# epoch 191/200
# 1/16, train_loss: 0.2643
# 2/16, train_loss: 0.3195
# 3/16, train_loss: 0.2632
# 4/16, train_loss: 0.0211
# 5/16, train_loss: 0.2037
# 6/16, train_loss: 0.1576
# 7/16, train_loss: 0.0875
# 8/16, train_loss: 0.1593
# 9/16, train_loss: 0.0974
# 10/16, train_loss: 0.2034
# 11/16, train_loss: 0.2281
# 12/16, train_loss: 0.3222
# 13/16, train_loss: 0.2077
# 14/16, train_loss: 0.3228
# 15/16, train_loss: 0.3215
# 16/16, train_loss: 0.1458
# epoch 191 average loss: 0.2078
# ----------
# epoch 192/200
# 1/16, train_loss: 0.1431
# 2/16, train_loss: 0.2168
# 3/16, train_loss: 0.2020
# 4/16, train_loss: 0.1457
# 5/16, train_loss: 0.0671
# 6/16, train_loss: 0.2069
# 7/16, train_loss: 0.0413
# 8/16, train_loss: 0.2613
# 9/16, train_loss: 0.1532
# 10/16, train_loss: 0.1465
# 11/16, train_loss: 0.1500
# 12/16, train_loss: 0.3818
# 13/16, train_loss: 0.2057
# 14/16, train_loss: 0.1441
# 15/16, train_loss: 0.2048
# 16/16, train_loss: 0.0892
# epoch 192 average loss: 0.1725
# current epoch: 192 current mean dice: 0.9231
# best mean dice: 0.9351 at epoch: 174
# ----------
# epoch 193/200
# 1/16, train_loss: 0.3253
# 2/16, train_loss: 0.0972
# 3/16, train_loss: 0.0849
# 4/16, train_loss: 0.3086
# 5/16, train_loss: 0.1517
# 6/16, train_loss: 0.1462
# 7/16, train_loss: 0.2028
# 8/16, train_loss: 0.0933
# 9/16, train_loss: 0.2081
# 10/16, train_loss: 0.2008
# 11/16, train_loss: 0.2669
# 12/16, train_loss: 0.1492
# 13/16, train_loss: 0.1696
# 14/16, train_loss: 0.1462
# 15/16, train_loss: 0.1458
# 16/16, train_loss: 0.1174
# epoch 193 average loss: 0.1759
# ----------
# epoch 194/200
# 1/16, train_loss: 0.1479
# 2/16, train_loss: 0.1457
# 3/16, train_loss: 0.2056
# 4/16, train_loss: 0.2033
# 5/16, train_loss: 0.1482
# 6/16, train_loss: 0.2098
# 7/16, train_loss: 0.2079
# 8/16, train_loss: 0.0995
# 9/16, train_loss: 0.2595
# 10/16, train_loss: 0.1625
# 11/16, train_loss: 0.1432
# 12/16, train_loss: 0.2758
# 13/16, train_loss: 0.2121
# 14/16, train_loss: 0.1424
# 15/16, train_loss: 0.0856
# 16/16, train_loss: 0.2629
# epoch 194 average loss: 0.1820
# current epoch: 194 current mean dice: 0.9223
# best mean dice: 0.9351 at epoch: 174
# ----------
# epoch 195/200
# 1/16, train_loss: 0.2636
# 2/16, train_loss: 0.0825
# 3/16, train_loss: 0.1862
# 4/16, train_loss: 0.0309
# 5/16, train_loss: 0.2111
# 6/16, train_loss: 0.2099
# 7/16, train_loss: 0.1637
# 8/16, train_loss: 0.2020
# 9/16, train_loss: 0.3676
# 10/16, train_loss: 0.1262
# 11/16, train_loss: 0.3049
# 12/16, train_loss: 0.2146
# 13/16, train_loss: 0.1245
# 14/16, train_loss: 0.2077
# 15/16, train_loss: 0.3224
# 16/16, train_loss: 0.2662
# epoch 195 average loss: 0.2052
# ----------
# epoch 196/200
# 1/16, train_loss: 0.0367
# 2/16, train_loss: 0.1081
# 3/16, train_loss: 0.2045
# 4/16, train_loss: 0.3255
# 5/16, train_loss: 0.1489
# 6/16, train_loss: 0.2040
# 7/16, train_loss: 0.2704
# 8/16, train_loss: 0.3236
# 9/16, train_loss: 0.2073
# 10/16, train_loss: 0.2136
# 11/16, train_loss: 0.2088
# 12/16, train_loss: 0.0864
# 13/16, train_loss: 0.2784
# 14/16, train_loss: 0.1350
# 15/16, train_loss: 0.1427
# 16/16, train_loss: 0.2267
# epoch 196 average loss: 0.1950
# current epoch: 196 current mean dice: 0.8355
# best mean dice: 0.9351 at epoch: 174
# ----------
# epoch 197/200
# 1/16, train_loss: 0.1712
# 2/16, train_loss: 0.2043
# 3/16, train_loss: 0.1846
# 4/16, train_loss: 0.1503
# 5/16, train_loss: 0.1458
# 6/16, train_loss: 0.2668
# 7/16, train_loss: 0.0900
# 8/16, train_loss: 0.0479
# 9/16, train_loss: 0.2620
# 10/16, train_loss: 0.2693
# 11/16, train_loss: 0.0286
# 12/16, train_loss: 0.0355
# 13/16, train_loss: 0.1376
# 14/16, train_loss: 0.2083
# 15/16, train_loss: 0.3822
# 16/16, train_loss: 0.2167
# epoch 197 average loss: 0.1751
# ----------
# epoch 198/200
# 1/16, train_loss: 0.2046
# 2/16, train_loss: 0.2037
# 3/16, train_loss: 0.0807
# 4/16, train_loss: 0.3268
# 5/16, train_loss: 0.2637
# 6/16, train_loss: 0.2806
# 7/16, train_loss: 0.2049
# 8/16, train_loss: 0.0880
# 9/16, train_loss: 0.1279
# 10/16, train_loss: 0.2684
# 11/16, train_loss: 0.1446
# 12/16, train_loss: 0.2629
# 13/16, train_loss: 0.0369
# 14/16, train_loss: 0.2712
# 15/16, train_loss: 0.1012
# 16/16, train_loss: 0.1386
# epoch 198 average loss: 0.1878
# current epoch: 198 current mean dice: 0.9334
# best mean dice: 0.9351 at epoch: 174
# ----------
# epoch 199/200
# 1/16, train_loss: 0.3223
# 2/16, train_loss: 0.2037
# 3/16, train_loss: 0.2648
# 4/16, train_loss: 0.2331
# 5/16, train_loss: 0.2072
# 6/16, train_loss: 0.1545
# 7/16, train_loss: 0.0343
# 8/16, train_loss: 0.1460
# 9/16, train_loss: 0.1212
# 10/16, train_loss: 0.2070
# 11/16, train_loss: 0.0952
# 12/16, train_loss: 0.1156
# 13/16, train_loss: 0.0290
# 14/16, train_loss: 0.0817
# 15/16, train_loss: 0.2736
# 16/16, train_loss: 0.2680
# epoch 199 average loss: 0.1723
# ----------
# epoch 200/200
# 1/16, train_loss: 0.1454
# 2/16, train_loss: 0.1478
# 3/16, train_loss: 0.0847
# 4/16, train_loss: 0.2073
# 5/16, train_loss: 0.2919
# 6/16, train_loss: 0.3277
# 7/16, train_loss: 0.2026
# 8/16, train_loss: 0.2610
# 9/16, train_loss: 0.1458
# 10/16, train_loss: 0.3229
# 11/16, train_loss: 0.0874
# 12/16, train_loss: 0.2644
# 13/16, train_loss: 0.3841
# 14/16, train_loss: 0.1451
# 15/16, train_loss: 0.1487
# 16/16, train_loss: 0.2036
# epoch 200 average loss: 0.2107
# current epoch: 200 current mean dice: 0.9277
# best mean dice: 0.9351 at epoch: 174

# %%
print(
    f"train completed, best_metric: {best_metric:.4f} "
    f"at epoch: {best_metric_epoch}")
# Out:
# train completed, best_metric: 0.9351 at epoch: 174

# %% [markdown]
# ## Plot the loss and metric

# %%
plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i + 1 for i in range(len(epoch_loss_values))]
y = epoch_loss_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.subplot(1, 2, 2)
plt.title("Val Mean Dice")
x = [val_interval * (i + 1) for i in range(len(metric_values))]
y = metric_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Check best model output with the input image and label

# %%
model.load_state_dict(torch.load(
    os.path.join(root_dir, "best_metric_model.pth")))
model.eval()
with torch.no_grad():
    for i, val_data in enumerate(val_loader):
        roi_size = (160, 160, 160)
        sw_batch_size = 4
        val_outputs = sliding_window_inference(
            val_data["image"].to(device), roi_size, sw_batch_size, model
        )
        # plot the slice [:, :, 80]
        plt.figure("check", (18, 6))
        plt.subplot(1, 3, 1)
        plt.title(f"image {i}")
        plt.imshow(val_data["image"][0, 0, :, :, 80], cmap="gray")
        plt.subplot(1, 3, 2)
        plt.title(f"label {i}")
        plt.imshow(val_data["label"][0, 0, :, :, 80])
        plt.subplot(1, 3, 3)
        plt.title(f"output {i}")
        plt.imshow(torch.argmax(
            val_outputs, dim=1).detach().cpu()[0, :, :, 80])
        plt.show()
        if i == 2:
            break
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# ## Evaluation on original image spacings

# %%
val_org_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys=["image", "label"]),
        Orientationd(keys=["image"], axcodes="RAS"),
        Spacingd(keys=["image"], pixdim=(
            1.5, 1.5, 2.0), mode="bilinear"),
        ScaleIntensityRanged(
            keys=["image"], a_min=-57, a_max=164,
            b_min=0.0, b_max=1.0, clip=True,
        ),
        CropForegroundd(keys=["image"], source_key="image"),
        EnsureTyped(keys=["image", "label"]),
    ]
)

val_org_ds = Dataset(
    data=val_files, transform=val_org_transforms)
val_org_loader = DataLoader(val_org_ds, batch_size=1, num_workers=4)

post_transforms = Compose([
    EnsureTyped(keys="pred"),
    Invertd(
        keys="pred",
        transform=val_org_transforms,
        orig_keys="image",
        meta_keys="pred_meta_dict",
        orig_meta_keys="image_meta_dict",
        meta_key_postfix="meta_dict",
        nearest_interp=False,
        to_tensor=True,
    ),
    AsDiscreted(keys="pred", argmax=True, to_onehot=2),
    AsDiscreted(keys="label", to_onehot=2),
])
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
model.load_state_dict(torch.load(
    os.path.join(root_dir, "best_metric_model.pth")))
model.eval()

with torch.no_grad():
    for val_data in val_org_loader:
        val_inputs = val_data["image"].to(device)
        roi_size = (160, 160, 160)
        sw_batch_size = 4
        val_data["pred"] = sliding_window_inference(
            val_inputs, roi_size, sw_batch_size, model)
        val_data = [post_transforms(i) for i in decollate_batch(val_data)]
        val_outputs, val_labels = from_engine(["pred", "label"])(val_data)
        # compute metric for current iteration
        dice_metric(y_pred=val_outputs, y=val_labels)

    # aggregate the final mean dice result
    metric_org = dice_metric.aggregate().item()
    # reset the status for next validation round
    dice_metric.reset()

print("Metric on original image spacing: ", metric_org)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Metric on original image spacing:  0.946885347366333

# %% [markdown]
# ## Cleanup data directory
#
# Remove directory if a temporary was used.

# %%
#if directory is None:
#    shutil.rmtree(root_dir)
